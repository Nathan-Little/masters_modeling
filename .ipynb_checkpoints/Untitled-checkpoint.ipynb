# %% [markdown]
# # Data Scraping from ESPN
#
# tournements: https://www.espn.com/golf/schedule/_/tour/pga

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load the inital page

# %%
source = urllib.request.urlopen('https://www.espn.com/golf/schedule/_/tour/pga/').read()
soup = BeautifulSoup(source,'lxml')

# %% [markdown]
# ### Get the table with completed tournements

# %%
table_titles = soup.findAll("section", {"class" : "ResponsiveTable"})
for table in table_titles:
    title = table.find("div", {"class" : "Table__Title"})
    if title.text == "Completed Tournaments":
        # This is the one that we want
        # Still saved in table
        break

# %% [markdown]
# ### Extract all tournement links from the table
#
# There are tournement links and player links. Tournement links do not have "player" in the path.

# %%
links = table.findAll('a', {'class' : "AnchorLink"})
tournement_links = []
for link in links: 
    href = link.attrs['href']
    if "player" not in href.split('/'):
        tournement_links.append(href)

# %%
def get_tournement_results(link):
    source = urllib.request.urlopen(link).read()
    soup = BeautifulSoup(source,'lxml')
    
    compet_table = soup.findAll("div", {"class" : "competitors"})
    tables = comet_table.findAll("section", {"class" : "ResponsiveTable"})
    for table in tables:
        #Get headings
        headings = []
        headings_tag = table.find('thead')

        for heading in headings_tag.findAll("th", {"class" : "Table_TH"}):
                headings.append(heading.text)
        if len(headings) < 8: 
            continue

        body = compet_table.find("tbody")
        rows = body.findAll('tr')
        player_data = []
        for row in rows:
            current_row = []
            for text in row.findAll("td"):
                current_row.append(text.text)

            player_data.append(current_row)
        return headings + player_data

# %%
def parse_results(results):
    '''Gets nodes and edges of victory graph'''
    data = []
    for p1 in range(len(results)):
        for p2 in range(p1, len(results)):
            try:
                player1 = results[p1]
                player2 = results[p2]
                # need to handle DQ
                
                # Change even to 0
                if player1[2] == "E":
                    player1[2] = 0
                if player2[2] == "E":
                    player2[2] = 0

                if player1[2] == "WD" or player2[2] == "WD":
                    # Not sure how to handle these
                    continue
                    
                if player2[2] == "CUT":
                    # player 2 was cut

                    if player1[2] == "CUT":
                        # player 1 was also cut, so tie
                        continue

                    else: 
                        # player1 was not cut
                        data.append([player1[1], player2[1]])
                        continue

                difference = int(player1[2]) - int(player2[2])
                if difference < 0:
                    data.append([player1[1], player2[1]])
                elif difference > 0:
                    data.append([player2[1], player1[1]])
            except Exception as err: 
                print(err)
                print(player1)
                print(player2)
    return data

# %%
tournement_links[1]
# Out:
# 'http://www.espn.com/golf/leaderboard?tournamentId=401148234'

# %%
data = []
for link in tournement_links[0:2]:
    try:
        results = get_tournement_results(link)
#         data.append(parse_results(results))
        df = pd.DataFrame(results, columns=['positon', 'name','score', 'r1', 'r2', 'r3','r4', 'total', 'winnings', 'x']).set_index('name')
        df[['r1', 'r2', 'r3', 'r4']] = df[['r1', 'r2', 'r3', 'r4']].replace("--", np.nan).astype(float)
        # Set types
        data.append(df)
        
    except Exception as err: 
        print(link)
        print(err)
# Out:
# http://www.espn.com/golf/leaderboard?tournamentId=401148234
# 10 columns passed, passed data had 2 columns

# %%
df = data[0]
df[['r1', 'r2', 'r3', 'r4']] = df[['r1', 'r2', 'r3', 'r4']].replace("--", np.nan).astype(float)
df.head()
# Out:
#                 positon score    r1    r2    r3    r4 total    winnings    x
# name
# Joaquin Niemann       1   -21  65.0  62.0  68.0  64.0   259  $1,350,000  500
# Tom Hoge              2   -15  68.0  65.0  67.0  65.0   265    $817,500  300
# Brian Harman         T3   -14  65.0  66.0  70.0  65.0   266    $366,094  134
# Harris English       T3   -14  66.0  65.0  68.0  67.0   266    $366,094  134
# Nate Lashley         T3   -14  68.0  64.0  65.0  69.0   266    $366,094  134

# %%
tounement_dfs = []
player_dict = {} # key : name, value : np array where true = win, false = loss, rows are rounds, index is other player
player_wins = {}
player_losses = {}
for df in data:
    all_rounds = df[['r1', 'r2', 'r3', 'r4']].values.T

    rows = []
    for i, name in enumerate(df.index): 
        player_rounds = df.loc[name, ['r1', 'r2', 'r3', 'r4']].values
        player_rounds = player_rounds.reshape(4, 1)
        diff = all_rounds - player_rounds #difference between scores per round
        wins = diff > 0 & (pd.notnull(diff))
        total_matches_arr = pd.notnull(diff).sum(axis=0) 
        total_matches_arr[i] = 0
        total_matches = total_matches_arr.sum()
        total_wins = wins.sum()
        total_losses = total_matches - total_wins


        # add wins and losses to the player's total
        if name in player_wins:
            player_wins[name] += total_wins
            player_losses[name] += total_losses
        else: 
            player_wins[name] = total_wins
            player_losses[name] = total_losses

        player_series = pd.Series(total_matches_arr, index=df.index)
        if name in player_dict: 
            player_dict[name] += player_series
        else:
            player_dict[name] = player_series
d = pd.DataFrame(player_dict, index=df.index)
d.index = d.columns
# tournement_dfs.append(d)

# %% [markdown]
# Player dict has each player as the key and a list with the player's index and a boolean matrix as the value. The rows of the boolean matrix are each round, and the columns are the player that they played against (by index)

# %% [markdown]
# ### Combine all of the dataframes

# %%
d = d*-1

# %%
d.head()
# Out:
#                  Joaquin Niemann  Tom Hoge  Brian Harman  Harris English  \
# Joaquin Niemann                0        -4            -4              -4
# Tom Hoge                      -4         0            -4              -4
# Brian Harman                  -4        -4             0              -4
# Harris English                -4        -4            -4               0
# Nate Lashley                  -4        -4            -4              -4
#
#                  Nate Lashley  Richy Werenski  Sebastian Munoz  \
# Joaquin Niemann            -4              -4               -4
# Tom Hoge                   -4              -4               -4
# Brian Harman               -4              -4               -4
# Harris English             -4              -4               -4
# Nate Lashley                0              -4               -4
#
#                  Scottie Scheffler  Robby Shelton  Viktor Hovland  ...  \
# Joaquin Niemann                 -4             -4              -4  ...
# Tom Hoge                        -4             -4              -4  ...
# Brian Harman                    -4             -4              -4  ...
# Harris English                  -4             -4              -4  ...
# Nate Lashley                    -4             -4              -4  ...
#
#                  Brendon de Jonge  Michael Gellerman  Conrad Shindler  \
# Joaquin Niemann                -2                 -2               -2
# Tom Hoge                       -2                 -2               -2
# Brian Harman                   -2                 -2               -2
# Harris English                 -2                 -2               -2
# Nate Lashley                   -2                 -2               -2
#
#                  Patton Kizzire  Mason Williams  Freddie Jacobson  \
# Joaquin Niemann              -2              -2                -2
# Tom Hoge                     -2              -2                -2
# Brian Harman                 -2              -2                -2
# Harris English               -2              -2                -2
# Nate Lashley                 -2              -2                -2
#
#                  Shawn Stefani  Joe Boros  Peter Malnati  Marc Leishman
# Joaquin Niemann             -2         -2             -3             -1
# Tom Hoge                    -2         -2             -3             -1
# Brian Harman                -2         -2             -3             -1
# Harris English              -2         -2             -3             -1
# Nate Lashley                -2         -2             -3             -1
#
# [5 rows x 156 columns]

# %%
v = []
for name in d.index:
    score = 1 + (1/2)*(player_wins[name] - player_losses[name])
    v.append(score)
    # set the diagonal
    d.loc[name, name] = player_wins[name] + player_losses[name] + 2
v = np.array(v)

# %%
x =  np.linalg.solve(d.values, v)

# %%
np.argsort(x)
# Out:
# array([153, 152, 155, 151, 150, 144, 147, 146, 148, 143, 145, 141, 139,
#        149, 140, 138, 135, 137, 134, 131, 142, 136, 123, 125, 119, 122,
#        127, 129, 130, 132, 121, 126, 128, 114, 115, 110, 106, 111, 120,
#        124, 107, 112, 117,  95,  96, 116,  98,  93,  97, 100,  99, 102,
#        133, 105, 103, 113, 109, 108,  86,  90,  88,  83, 118, 104, 101,
#         87,  92,  85,  84,  66,  91,  63,  71,  76,  74,  64,  72,  80,
#         82,  78,  52,  79,  75,  81,  89,  94,  67,  73,  70,  77,  68,
#         69,  56,  59,  58,  48,  51,  65,  57,  54,  46,  60,  40,  35,
#         30,  49,  36,  37,  62,  50,  43,  41,  39,  34,  53,  47,  23,
#         25,  31,  42,  38,  61,  45,  29,  27,  44,  13,  28,  55,  19,
#          9,  15,  24,  16,  33,  32,  21,  20,  26,  22,  14,  11,   6,
#         17,  12,  18,  10, 154,   4,   7,   8,   1,   5,   2,   3,   0])

# %%
def get_rankings(rankings, names):
    rank_indexes = np.argsort(rankings)
    ranked_names = [0]*len(names)
    for i in range(len(names)):
        ranked_names[i] = names[rank_indexes[i]]
    ranked_names.reverse()
    return ranked_names

# %%
get_rankings(x, d.index)
# Out:
# ['Joaquin Niemann',
#  'Harris English',
#  'Brian Harman',
#  'Richy Werenski',
#  'Tom Hoge',
#  'Robby Shelton',
#  'Scottie Scheffler',
#  'Nate Lashley',
#  'Peter Malnati',
#  'Matt Jones',
#  'Harold Varner III',
#  'Lanto Griffin',
#  'Adam Long',
#  'Sebastian Munoz',
#  'Mark Hubbard',
#  'Austin Cook',
#  'Sungjae Im',
#  'Cameron Smith',
#  'Bronson Burgoon',
#  'Harry Higgs',
#  'Morgan Hoffmann',
#  'Sam Ryder',
#  'Joseph Bramlett',
#  'Rob Oppenheim',
#  'Kevin Na',
#  'Viktor Hovland',
#  'Scott Piercy',
#  'Patrick Rodgers',
#  'Scott Harrington',
#  'Bud Cauley',
#  'Grayson Murray',
#  'Zack Sucher',
#  'Keegan Bradley',
#  'Mark D. Anderson',
#  'Jason Dufner',
#  'Hank Lebioda',
#  'D.J. Trahan',
#  'Doug Ghim',
#  'Doc Redman',
#  'Nick Taylor',
#  'Martin Laird',
#  'Byeong-Hun An',
#  'Scott Brown',
#  'Cameron Tringale',
#  'Joel Dahmen',
#  'Andrew Novak',
#  'Vince Covello',
#  'Cameron Percy',
#  'Peter Uihlein',
#  'Brice Garnett',
#  'Sung Kang',
#  'Denny McCarthy',
#  'Danny Lee',
#  'Brendan Steele',
#  'Russell Henley',
#  'Jonathan Byrd',
#  'Tyler McCumber',
#  'Roberto Castro',
#  'Robert Streb',
#  'Dominic Bozzelli',
#  'Bubba Watson',
#  'J.J. Spaun',
#  'Rhein Gibson',
#  'David Hearn',
#  'Ted Potter Jr.',
#  'Nick Watney',
#  'Kevin Streelman',
#  'J.B. Holmes',
#  'Sepp Straka',
#  'Matt Every',
#  'Jimmy Walker',
#  'Kyoung-Hoon Lee',
#  'Tyler Duncan',
#  'Fabian Gomez',
#  'Adam Schenk',
#  'Kevin Chappell',
#  'Talor Gooch',
#  'Chase Seiffert',
#  'Matthew NeSmith',
#  'Seamus Power',
#  'Sebastian Cappelen',
#  'Scott Stallings',
#  'Jason Kokrak',
#  'Bo Hoag',
#  'Johnson Wagner',
#  'Ben Taylor',
#  'Beau Hossler',
#  'Ryan Armour',
#  'Bryson DeChambeau',
#  'Tom Lewis',
#  'Nelson Lauta Ledesma',
#  'Anirban Lahiri',
#  'Brendon Todd',
#  'Vincent Whaley',
#  'Zach Johnson',
#  'Rafael Campos',
#  'Rod Pampling',
#  'Sam Burns',
#  'Brian Stuard',
#  'Jim Herman',
#  'Martin Trainer',
#  'David Lingmerth',
#  'Kyle Westmoreland',
#  'Maverick McNealy',
#  'Russell Knox',
#  'Hayden Springer',
#  'Xin-Jun Zhang',
#  'Carlos Ortiz',
#  'George McNeill',
#  'Whee Kim',
#  'John Huh',
#  'Boo Weekley',
#  'Ben Crane',
#  'Michael Kim',
#  'Andrew Landry',
#  'Ryan Brehm',
#  'Arjun Atwal',
#  'Daniel Summerhays',
#  'Henrik Norlander',
#  'Wes Roach',
#  'Tim Wilkinson',
#  'Billy Hurley III',
#  'Bill Haas',
#  'Jamie Lovemark',
#  'Branden Grace',
#  'Chris Baker',
#  'Mackenzie Hughes',
#  'J.J. Henry',
#  'John Senden',
#  'Josh Teater',
#  'Michael Gligic',
#  'Sang-Moon Bae',
#  'Roger Sloan',
#  'Steve Allan',
#  'Brandon Hagy',
#  'Kramer Hickok',
#  'Shintaro Ban',
#  'John Daly',
#  'Zac Blair',
#  'Cameron Davis',
#  'Alex Cejka',
#  'Davey Jude',
#  'Patton Kizzire',
#  'Robert Garrigus',
#  'John Rollins',
#  'Ryan Blaum',
#  'D.A. Points',
#  'Conrad Shindler',
#  'Brendon de Jonge',
#  'Michael Gellerman',
#  'Kristoffer Ventura',
#  'Mason Williams',
#  'Freddie Jacobson',
#  'Marc Leishman',
#  'Shawn Stefani',
#  'Joe Boros']

# %%
sum = 0
for i in data: 
    sum += len(i)
print(sum)
# Out:
# 7861

# %% [markdown]
# ### Make the list one dimensional

# %%
data_list = [] # one dimensional list
for row in data:
     data_list += row

# %%
import pandas as pd

# %%
df = pd.DataFrame(data_list, columns=['winner', "loser"])
df.head()
# Out:
#             winner           loser
# 0  Joaquin Niemann        Tom Hoge
# 1  Joaquin Niemann    Brian Harman
# 2  Joaquin Niemann  Harris English
# 3  Joaquin Niemann    Nate Lashley
# 4  Joaquin Niemann  Richy Werenski

# %%
pd.get_dummies(df['winner']).sum()
# Out:
# Adam Long         136
# Andrew Novak      108
# Austin Cook       136
# Beau Hossler       87
# Brendan Steele    108
#                  ...
# Tom Hoge          152
# Tyler McCumber     98
# Viktor Hovland    142
# Vince Covello      98
# Zack Sucher       124
# Length: 67, dtype: int64

# %%
players = {}
for match in data_list:
    if match[0] not in players:
        players[match[0]] = {'win_against' : [], 'lose_against' : []}
        
    if match[1] not in players:
        players[match[1]] = {'win_against' : [], 'lose_against' : []}
    
    players[match[0]]['win_against'].append(match[1])
    players[match[1]]['lose_against'].append(match[1])

# %%
player_df = pd.DataFrame(players)
player_df.head()
# Out:
#                                                 Joaquin Niemann  \
# win_against   [Tom Hoge, Brian Harman, Harris English, Nate ...
# lose_against                                                 []
#
#                                                        Tom Hoge  \
# win_against   [Brian Harman, Harris English, Nate Lashley, R...
# lose_against                                         [Tom Hoge]
#
#                                                    Brian Harman  \
# win_against   [Sebastian Munoz, Scottie Scheffler, Robby She...
# lose_against                       [Brian Harman, Brian Harman]
#
#                                                  Harris English  \
# win_against   [Sebastian Munoz, Scottie Scheffler, Robby She...
# lose_against                   [Harris English, Harris English]
#
#                                                    Nate Lashley  \
# win_against   [Sebastian Munoz, Scottie Scheffler, Robby She...
# lose_against                       [Nate Lashley, Nate Lashley]
#
#                                                  Richy Werenski  \
# win_against   [Sebastian Munoz, Scottie Scheffler, Robby She...
# lose_against                   [Richy Werenski, Richy Werenski]
#
#                                                 Sebastian Munoz  \
# win_against   [Viktor Hovland, Matt Jones, Mark Hubbard, Lan...
# lose_against  [Sebastian Munoz, Sebastian Munoz, Sebastian M...
#
#                                               Scottie Scheffler  \
# win_against   [Viktor Hovland, Matt Jones, Mark Hubbard, Lan...
# lose_against  [Scottie Scheffler, Scottie Scheffler, Scottie...
#
#                                                   Robby Shelton  \
# win_against   [Viktor Hovland, Matt Jones, Mark Hubbard, Lan...
# lose_against  [Robby Shelton, Robby Shelton, Robby Shelton, ...
#
#                                                  Viktor Hovland  ...  \
# win_against   [Lanto Griffin, Bud Cauley, Austin Cook, Kevin...  ...
# lose_against  [Viktor Hovland, Viktor Hovland, Viktor Hovlan...  ...
#
#                                              Kristoffer Ventura  \
# win_against                                                  []
# lose_against  [Kristoffer Ventura, Kristoffer Ventura, Krist...
#
#                                                      Ryan Blaum  \
# win_against                                                  []
# lose_against  [Ryan Blaum, Ryan Blaum, Ryan Blaum, Ryan Blau...
#
#                                                Brendon de Jonge  \
# win_against                                                  []
# lose_against  [Brendon de Jonge, Brendon de Jonge, Brendon d...
#
#                                               Michael Gellerman  \
# win_against                                                  []
# lose_against  [Michael Gellerman, Michael Gellerman, Michael...
#
#                                                 Conrad Shindler  \
# win_against                                                  []
# lose_against  [Conrad Shindler, Conrad Shindler, Conrad Shin...
#
#                                                  Patton Kizzire  \
# win_against                                                  []
# lose_against  [Patton Kizzire, Patton Kizzire, Patton Kizzir...
#
#                                                  Mason Williams  \
# win_against                                                  []
# lose_against  [Mason Williams, Mason Williams, Mason William...
#
#                                                Freddie Jacobson  \
# win_against                                                  []
# lose_against  [Freddie Jacobson, Freddie Jacobson, Freddie J...
#
#                                                   Shawn Stefani  \
# win_against                                                  []
# lose_against  [Shawn Stefani, Shawn Stefani, Shawn Stefani, ...
#
#                                                       Joe Boros
# win_against                                                  []
# lose_against  [Joe Boros, Joe Boros, Joe Boros, Joe Boros, J...
#
# [2 rows x 154 columns]

# %%
winner_dict = {} # Number of each times a player beat the other (winner is row, loser is col)
total_match_dict = {} # Sum of total number of times each player played the other
for winner in df['winner'].unique():
    winner_dict[winner] = {winner : 0}
    for loser in df[df['winner'] == winner]['loser']:
        if loser not in winner_dict[winner]:
            # They havent played yet
            winner_dict[winner][loser] = 0
            
        winner_dict[winner][loser] += 1

# %%
winner_dict
# Out:
# {'Joaquin Niemann': {'Tom Hoge': 1,
#   'Brian Harman': 1,
#   'Harris English': 1,
#   'Nate Lashley': 1,
#   'Richy Werenski': 1,
#   'Sebastian Munoz': 1,
#   'Scottie Scheffler': 1,
#   'Robby Shelton': 1,
#   'Viktor Hovland': 1,
#   'Matt Jones': 1,
#   'Mark Hubbard': 1,
#   'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Tom Hoge': {'Brian Harman': 1,
#   'Harris English': 1,
#   'Nate Lashley': 1,
#   'Richy Werenski': 1,
#   'Sebastian Munoz': 1,
#   'Scottie Scheffler': 1,
#   'Robby Shelton': 1,
#   'Viktor Hovland': 1,
#   'Matt Jones': 1,
#   'Mark Hubbard': 1,
#   'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Brian Harman': {'Sebastian Munoz': 1,
#   'Scottie Scheffler': 1,
#   'Robby Shelton': 1,
#   'Viktor Hovland': 1,
#   'Matt Jones': 1,
#   'Mark Hubbard': 1,
#   'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Harris English': {'Sebastian Munoz': 1,
#   'Scottie Scheffler': 1,
#   'Robby Shelton': 1,
#   'Viktor Hovland': 1,
#   'Matt Jones': 1,
#   'Mark Hubbard': 1,
#   'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Nate Lashley': {'Sebastian Munoz': 1,
#   'Scottie Scheffler': 1,
#   'Robby Shelton': 1,
#   'Viktor Hovland': 1,
#   'Matt Jones': 1,
#   'Mark Hubbard': 1,
#   'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Richy Werenski': {'Sebastian Munoz': 1,
#   'Scottie Scheffler': 1,
#   'Robby Shelton': 1,
#   'Viktor Hovland': 1,
#   'Matt Jones': 1,
#   'Mark Hubbard': 1,
#   'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Sebastian Munoz': {'Viktor Hovland': 1,
#   'Matt Jones': 1,
#   'Mark Hubbard': 1,
#   'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Scottie Scheffler': {'Viktor Hovland': 1,
#   'Matt Jones': 1,
#   'Mark Hubbard': 1,
#   'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Robby Shelton': {'Viktor Hovland': 1,
#   'Matt Jones': 1,
#   'Mark Hubbard': 1,
#   'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Viktor Hovland': {'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Matt Jones': {'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Mark Hubbard': {'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Lanto Griffin': {'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Bud Cauley': {'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Austin Cook': {'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Kevin Na': {'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
# ...
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Rhein Gibson': {'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Russell Henley': {'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Jason Dufner': {'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Cameron Percy': {'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Johnson Wagner': {'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Sebastian Cappelen': {'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Robert Streb': {'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Beau Hossler': {'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1}}

# %% [markdown]
# ### Match Dataframe
# Winner is the row index, column index is the loser.
#
# The value is the number of times that the winner beat the loser.

# %%
match_df = pd.DataFrame(winner_dict).fillna(0).astype(int)

# %%
wins = match_df.sum(axis=1)
losses = match_df.sum(axis=0)
total = wins + losses

# %% [markdown]
# ### Make the vector v

# %%
match_df.head()
# Out:
#                 Joaquin Niemann  Tom Hoge  Brian Harman  Harris English  \
# Tom Hoge                      1         0             0               0
# Brian Harman                  1         1             0               0
# Harris English                1         1             0               0
# Nate Lashley                  1         1             0               0
# Richy Werenski                1         1             0               0
#
#                 Nate Lashley  Richy Werenski  Sebastian Munoz  \
# Tom Hoge                   0               0                0
# Brian Harman               0               0                0
# Harris English             0               0                0
# Nate Lashley               0               0                0
# Richy Werenski             0               0                0
#
#                 Scottie Scheffler  Robby Shelton  Viktor Hovland  ...  \
# Tom Hoge                        0              0               0  ...
# Brian Harman                    0              0               0  ...
# Harris English                  0              0               0  ...
# Nate Lashley                    0              0               0  ...
# Richy Werenski                  0              0               0  ...
#
#                 Roberto Castro  J.J. Spaun  Rhein Gibson  Russell Henley  \
# Tom Hoge                     0           0             0               0
# Brian Harman                 0           0             0               0
# Harris English               0           0             0               0
# Nate Lashley                 0           0             0               0
# Richy Werenski               0           0             0               0
#
#                 Jason Dufner  Cameron Percy  Johnson Wagner  \
# Tom Hoge                   0              0               0
# Brian Harman               0              0               0
# Harris English             0              0               0
# Nate Lashley               0              0               0
# Richy Werenski             0              0               0
#
#                 Sebastian Cappelen  Robert Streb  Beau Hossler
# Tom Hoge                         0             0             0
# Brian Harman                     0             0             0
# Harris English                   0             0             0
# Nate Lashley                     0             0             0
# Richy Werenski                   0             0             0
#
# [5 rows x 67 columns]

# %%
match_df.describe()
# Out:
#        Joaquin Niemann    Tom Hoge  Brian Harman  Harris English  \
# count            153.0  153.000000    153.000000      153.000000
# mean               1.0    0.993464      0.967320        0.967320
# std                0.0    0.080845      0.178381        0.178381
# min                1.0    0.000000      0.000000        0.000000
# 25%                1.0    1.000000      1.000000        1.000000
# 50%                1.0    1.000000      1.000000        1.000000
# 75%                1.0    1.000000      1.000000        1.000000
# max                1.0    1.000000      1.000000        1.000000
#
#        Nate Lashley  Richy Werenski  Sebastian Munoz  Scottie Scheffler  \
# count    153.000000      153.000000       153.000000         153.000000
# mean       0.967320        0.967320         0.947712           0.947712
# std        0.178381        0.178381         0.223337           0.223337
# min        0.000000        0.000000         0.000000           0.000000
# 25%        1.000000        1.000000         1.000000           1.000000
# 50%        1.000000        1.000000         1.000000           1.000000
# 75%        1.000000        1.000000         1.000000           1.000000
# max        1.000000        1.000000         1.000000           1.000000
#
#        Robby Shelton  Viktor Hovland  ...  Roberto Castro  J.J. Spaun  \
# count     153.000000      153.000000  ...      153.000000  153.000000
# mean        0.947712        0.928105  ...        0.601307    0.601307
# std         0.223337        0.259163  ...        0.491237    0.491237
# min         0.000000        0.000000  ...        0.000000    0.000000
# 25%         1.000000        1.000000  ...        0.000000    0.000000
# 50%         1.000000        1.000000  ...        1.000000    1.000000
# 75%         1.000000        1.000000  ...        1.000000    1.000000
# max         1.000000        1.000000  ...        1.000000    1.000000
#
#        Rhein Gibson  Russell Henley  Jason Dufner  Cameron Percy  \
# count    153.000000      153.000000    153.000000     153.000000
# mean       0.601307        0.601307      0.601307       0.594771
# std        0.491237        0.491237      0.491237       0.492549
# min        0.000000        0.000000      0.000000       0.000000
# 25%        0.000000        0.000000      0.000000       0.000000
# 50%        1.000000        1.000000      1.000000       1.000000
# 75%        1.000000        1.000000      1.000000       1.000000
# max        1.000000        1.000000      1.000000       1.000000
#
#        Johnson Wagner  Sebastian Cappelen  Robert Streb  Beau Hossler
# count      153.000000          153.000000    153.000000    153.000000
# mean         0.581699            0.581699      0.575163      0.568627
# std          0.494900            0.494900      0.495942      0.496894
# min          0.000000            0.000000      0.000000      0.000000
# 25%          0.000000            0.000000      0.000000      0.000000
# 50%          1.000000            1.000000      1.000000      1.000000
# 75%          1.000000            1.000000      1.000000      1.000000
# max          1.000000            1.000000      1.000000      1.000000
#
# [8 rows x 67 columns]

# %%
v_series = 1 + (1/2)*(wins - losses)

# %% [markdown]
# Validate v with Tiger Woods

# %%
(1 + (1/2)*(wins['Tiger Woods'] - losses['Tiger Woods'])) == v_series['Tiger Woods']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4735             try:
# -> 4736                 return libindex.get_value_box(s, key)
#    4737             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-180-4563027c84bf> in <module>
# ----> 1 (1 + (1/2)*(wins['Tiger Woods'] - losses['Tiger Woods'])) == v_series['Tiger Woods']
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1066         key = com.apply_if_callable(key, self)
#    1067         try:
# -> 1068             result = self.index.get_value(self, key)
#    1069
#    1070             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4742                     raise InvalidIndexError(key)
#    4743                 else:
# -> 4744                     raise e1
#    4745             except Exception:  # pragma: no cover
#    4746                 raise e1
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tiger Woods'

# %% [markdown]
# ### Make the matrix A
#
# We need total matches against each person

# %%
total_matches = {}
for player in match_df: # iterates over rows
    # For every other player
    # add the wins and losses
    if player not in total_matches:
        total_matches[player] = {}
        
    for other in match_df: # for every other player
        if other not in total_matches:
            total_matches[other] = {}
            
        if player == other:
            # Same player make it 2 + total matches
#             total_matches[player][other] = 2 + total[player]
            total_matches[player][other] = 0
            
        else:
            total_matches[player][other] = -1*(match_df.loc[player, other] + match_df.loc[other, player])
            total_matches[other][player] = total_matches[player][other]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Joaquin Niemann'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-213-456cf0fc9ebc> in <module>
#      16
#      17         else:
# ---> 18             total_matches[player][other] = -1*(match_df.loc[player, other] + match_df.loc[other, player])
#      19             total_matches[other][player] = total_matches[player][other]
#      20
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     803     def _getitem_tuple(self, tup):
#     804         try:
# --> 805             return self._getitem_lowerdim(tup)
#     806         except IndexingError:
#     807             pass
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     927         for i, key in enumerate(tup):
#     928             if is_label_like(key) or isinstance(key, tuple):
# --> 929                 section = self._getitem_axis(key, axis=i)
#     930
#     931                 # we have yielded a scalar ?
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1848         # fall thru to straight lookup
#    1849         self._validate_key(key, axis)
# -> 1850         return self._get_label(key, axis=axis)
#    1851
#    1852
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     158             raise IndexingError("no slices here, handle elsewhere")
#     159
# --> 160         return self.obj._xs(label, axis=axis)
#     161
#     162     def _get_loc(self, key: int, axis: int):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3735             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3736         else:
# -> 3737             loc = self.index.get_loc(key)
#    3738
#    3739             if isinstance(loc, np.ndarray):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Joaquin Niemann'

# %% [markdown]
# The values of this dataframe form the matrix A

# %%
total_matches_df = pd.DataFrame(total_matches).astype(int)
total_matches_df.head()
# Out:
#                  Joaquin Niemann  Tom Hoge  Brian Harman  Harris English  \
# Joaquin Niemann                0        -3            -4              -5
# Tom Hoge                      -3         0            -5              -8
# Brian Harman                  -4        -5             0              -5
# Harris English                -5        -8            -5               0
# Nate Lashley                  -2        -2            -1              -2
#
#                  Nate Lashley  Richy Werenski  Sebastian Munoz  \
# Joaquin Niemann            -2              -3               -3
# Tom Hoge                   -2              -5               -6
# Brian Harman               -1              -2               -4
# Harris English             -2              -3               -6
# Nate Lashley                0               0               -3
#
#                  Scottie Scheffler  Robby Shelton  Viktor Hovland  ...  \
# Joaquin Niemann                 -5             -5              -4  ...
# Tom Hoge                        -5             -7              -3  ...
# Brian Harman                    -6             -5              -4  ...
# Harris English                  -6             -8              -4  ...
# Nate Lashley                    -3             -3              -3  ...
#
#                  David Lingmerth  MJ Daffue  Brendon de Jonge  Jay McLuen  \
# Joaquin Niemann               -1          0                -1           0
# Tom Hoge                      -2          0                -1           0
# Brian Harman                  -1          0                -1           0
# Harris English                -2          0                -1           0
# Nate Lashley                  -1          0                -1           0
#
#                  Daniel Chopra  Tom Lewis  Hayden Buckley  Sam Saunders  \
# Joaquin Niemann              0         -2              -1            -1
# Tom Hoge                     0         -2              -1            -3
# Brian Harman                 0         -1              -1            -2
# Harris English              -1         -3              -1            -2
# Nate Lashley                 0         -1               0            -1
#
#                  Rod Perry  Davis Love III
# Joaquin Niemann         -1              -1
# Tom Hoge                -1              -1
# Brian Harman            -1              -3
# Harris English          -1              -3
# Nate Lashley            -1              -1
#
# [5 rows x 303 columns]

# %% [markdown]
# Now we need to make sure that v is in the correct order

# %%
sum_df = total_matches_df.sum()*-1

# %%
sum_df['Tom Hoge']
# Out:
# 969

# %%
total['Tom Hoge']
# Out:
# 1017.0

# %%
total_matches_df['Tom Hoge'].sum() - 1019 + total['Tom Hoge']
# Out:
# 48.0

# %%
import numpy as np

# %%
v_lst = []
for player in total_matches_df: # goes in order of the rows
    v_lst.append(v_series[player])
    
v = np.array(v_lst)

# %%
v[0]
# Out:
# 13.5

# %%
A = total_matches_df.values

# %%
rankings_arr = np.linalg.solve(A, v)

# %%
np.amax(rankings)
# Out:
# 0.25

# %%
rankings = {}
for i in range(len(rankings_arr)):
    rankings[total_matches_df.index[i]] = rankings_arr[i]
rankings = pd.Series(rankings)

# %%
rankings
# Out:
# Joaquin Niemann   -0.438461
# Tom Hoge          -0.553864
# Brian Harman      -0.520519
# Harris English    -0.735778
# Nate Lashley      -0.424828
#                      ...
# Tom Lewis         -0.169049
# Hayden Buckley    -0.417729
# Sam Saunders      -0.125463
# Rod Perry         -0.443530
# Davis Love III    -0.124328
# Length: 303, dtype: float64

# %%
rankings.sort_values()
# Out:
# Rory McIlroy        -0.927810
# Tyrrell Hatton      -0.919660
# Jon Rahm            -0.895888
# Patrick Reed        -0.801863
# Bryson DeChambeau   -0.771709
#                        ...
# Yongjun Bae (a)     -0.016577
# Marcus Kinhult      -0.012190
# Whee Kim             0.001258
# Michael Kim          0.002154
# Yi Keun Chang        0.021820
# Length: 303, dtype: float64

# %%
new_df = pd.DataFrame(pd.concat([rankings, wins, losses, total], axis=1))
# Out:
# /Users/chrisamoroso/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
new_df.head()
# Out:
#                        0    1      2      3
# 3               0.250000    1    1.0    2.0
# Aaron Baddeley -0.457617  364  413.0  777.0
# Aaron Wise     -0.395688  321  309.0  630.0
# Abraham Ancer  -0.603094  279  510.0  789.0
# Adam Hadwin    -0.622431  134  264.0  398.0

# %%
df.sort_values(by=0, axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-136-52c4e7ec5951> in <module>
# ----> 1 df.sort_values(by=0, axis=0)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4991
#    4992             by = by[0]
# -> 4993             k = self._get_label_or_level_values(by, axis=axis)
#    4994
#    4995             if isinstance(ascending, (tuple, list)):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1772             values = self.axes[axis].get_level_values(key)._values
#    1773         else:
# -> 1774             raise KeyError(key)
#    1775
#    1776         # Check for duplicates
#
# KeyError: 0
