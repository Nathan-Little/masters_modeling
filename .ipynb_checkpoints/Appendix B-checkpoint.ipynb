# %% [markdown]
# # Massey Matrix

# %% [markdown]
# ### Outline
# - Weighting Calculations
# - Importing Data
# - Building Massey Matrix
# - Solving matrix
# - Ranking
# - Model Validation with one tournement
# - Model Validation with 2019 Masters

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ## Weighting
# We use the logistic function to weight tournements, so early tournements have a smaller influence and more recent tournements have a larger influence.
#
# We also increase the weight of previous majors, and further increase previous masters.
#
# The weighting of tournments vary as follows:
# + Normal tournement: (.5, .7)
# + Non-Masters majors: (.7 : .9)
# + Masters: (.9, 1.1)

# %%
MAJORS_IDS = {"2010" : [797, 798, 799],
            "2011" : [981, 982, 983],
             "2012" : [1013, 1017, 1018], 
              "2013" : [1200, 1204, 1206], 
              "2014" : [1325, 1329, 1330], 
              "2015" : [2249, 2253, 2255], 
              "2016" : [2501, 2505, 2507], 
              "2017" : [3066, 2710, 2712], 
              "2018" : [401025255, 401025259, 401025263], 
              "2019" : [401056552, 401056556, 401056547], 
              "2020" : [], 
             }
MASTERS_IDS = {"2010" : 774, 
              "2011" : 980,
             "2012" : 1005, 
              "2013" : 1192, 
              "2014" : 1317, 
              "2015" : 2241, 
              "2016" : 2493, 
              "2017" : 2700, 
              "2018" : 401025221, 
              "2019" : 401056527, 
              "2020" : 0, 
              }

# %% [markdown]
# These functions calculate the weight for each tournement.

# %%
from scipy.special import expit

# %%
def sigmoid_x_map(num):
    '''Maps an integer x (0, 10) to (-6, 6)'''
    return -6 + ((num/10) * 12)

def year_int(year):
    return int(year[-2:]) - 10

def masters(year):
    '''-6 < year < 6'''
    return (.6 + .4 * expit(year))
def major(year):
    return (.2 + .5 * expit(year))
def non_major(year):
    return (.1 + .4 * expit(year))

def get_weight(year, tourn_id):
    num = year_int(year)
    if tourn_id == MASTERS_IDS[year]:
        x = sigmoid_x_map(num)
        return masters(x)
    elif tourn_id in MAJORS_IDS[year]:
        x = sigmoid_x_map(num)
        return major(x)
    else:
        x = sigmoid_x_map(num)
        return non_major(x)

# %%
import matplotlib.pyplot as plt
years = ['2010', '2011', '2012', '2013', '2014', '2015',
         '2016', '2017', '2018', '2019', '2020']
x = np.array([sigmoid_x_map(year_int(x)) for x in years])
masters_weights =  masters(x)
majors_weights =  major(x)
non_majors_weights = non_major(x)
fig = plt.figure()
fig.suptitle('Weights')
plt.xlabel('Year')
plt.ylabel('Weight')
plt.plot(years, masters_weights, color='green', label='Masters')
plt.plot(years, majors_weights, color='blue', label='Major')
plt.plot(years, non_majors_weights, color='red', label='Non-Major')
plt.legend()
plt.show()

# %% [markdown]
# ## Import previously scraped data
#
# Within the data folder, there is a subfolder for each year. Each year folder contains csv files with player data for each tournement. The name of the folder is the tournemnet ID from ESPN (found in the URL).

# %% [markdown]
# Open every file in each year folder and save them as a Pandas dataframe.
# Put each dataframe in a dictionary with its specific weight.

# %%
import os
dfs = {}
weights = []
for year in os.listdir('data'):
    if year[0] == '2':
        # if the file is a year (there are some other files in the folder)
        dfs[year] = []
        for file in os.listdir('data/' + year):
            # Note: file = tournementID
            weight = get_weight(year, file)
            df = pd.read_csv('data/' + year + '/' +file).set_index("PLAYER")
            old_len = len(df)
            df = df.drop_duplicates()
            if len(df) != old_len:
                pass
            dfs[year].append((df, weight))

# %%
df.head()
# Out:
#                   POS TO PAR    R1    R2    R3    R4  TOT    EARNINGS  \
# PLAYER
# Branden Grace       1     -9  66.0  74.0  69.0  66.0  275  $1,062,000
# Russell Knox       T2     -7  72.0  65.0  73.0  67.0  277    $519,200
# Luke Donald        T2     -7  66.0  71.0  69.0  71.0  277    $519,200
# Bryson DeChambeau  T4     -5  70.0  69.0  72.0  68.0  279    $259,600
# Kevin Na           T4     -5  73.0  71.0  66.0  69.0  279    $259,600
#
#                    FEDEX PTS
# PLAYER
# Branden Grace            500
# Russell Knox             245
# Luke Donald              245
# Bryson DeChambeau          0
# Kevin Na                 123

# %% [markdown]
# Remove all of the amateurs and people who withdrew or were disqualified from the dataset.
#
# When a player withdraws, they get a score of whatever they had when they withdrew—42 through 9 holes, for example— so it looks like the got a 42 on the round and beat everybody.
#
# People who were cut after two days are still in the dataset. They are considered to play a "game" against every other player on the first two days, but not on the last two. Including rounds not played as losses would extrapolate poor performance on the first two days to the last two days, which would introduce bias.

# %%
clean_data = {}
for year in dfs: 
    clean_data[year] = []
    for df, weight in dfs[year]:
        split_names = [] 
        for player in df.index: 
            split_names.append(player.split(' '))
        df['name_arr'] = split_names 
        df['pro'] = df['name_arr'].apply(lambda arr : arr[-1] != '(a)')
        df = df[df.pro]
        df['finished'] = df['TO PAR'].apply(lambda s : s != "WD" and s != "DQ")
        df = df[df.finished]
        clean_data[year].append((df, weight))
# Out:
# /Users/chrisamoroso/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ### Building Massey Matrix
#
# To validate our results, we are test the algorithm with one tournement. For simplicity, we used the first one in the dataset.

# %%
def add_dicts(s1, s2):
    '''Function that adds the values of two pandas series'''
    result = {}
    for name in s1:
        if name in s2: 
            result[name] = s1[name] + s2[name]
        else: 
            result[name] = s1[name]
            
    for name in s2: 
        if name not in s1:
            result[name] = s2[name]
    return result

# %%
tounement_dfs = []
player_dict = {}
# key : name, value : np array where true = win, false = loss, rows are rounds, index is other player
player_wins = {}
player_losses = {}
player_total = {}
massey_dict = {}
columns = []
rows = []
test_dfs = []
player_totals = {}
for year in clean_data:
    print(year)
    for df, weight in clean_data[year]:
#         weight = 1
        # 4 X num players matrix (numpy)
        all_rounds = df[['R1', 'R2', 'R3', 'R4']].values.T
    #     print(all_rounds)
        rows = []
        test_dfs.append(df)
        for i, name in enumerate(df.index): 
            player_rounds = df.loc[name, ['R1', 'R2', 'R3', 'R4']].values
            if len(player_rounds) == 2:
                print(player_rounds)
                print(name)
                print(df)
                break
            try:
                player_rounds = player_rounds.reshape(4, 1)
            except: 
                player_rounds = player_rounds[0].reshape(4, 1)
            #difference between scores per round
            # positive implies a win, negative is a loss
            win_diff = all_rounds - player_rounds                

#             wins = win_diff[pd.notnull(win_diff)]
#             wins = wins[wins > 0] 
#             total_wins = len(wins)
#                 wins = pd.notnull(win_diff) & win_diff > 0
            # NUmber of "games" against each 
            # player in the tournement
            total_matches_arr = pd.notnull(win_diff).sum(axis=0) 
            # Number of games against yourself is 0
            total_matches_arr[i] = 0
#                 total_matches_arr = total_matches_arr * weight
            total_matches = total_matches_arr.sum()
#                 total_losses = total_matches - total_wins
#                 weighted_wins = total_wins * weight
#                 weighted_losses = total_losses * weight

            #massey method 
            # weighted number of matches against each person
            weighted_total_matches = total_matches_arr*weight
            where_are_NaNs = pd.isnull(win_diff)
            win_diff[where_are_NaNs] = 0
            # Total win differential
            massey_sum = win_diff.sum()
            # APPLY WEIGHTING
            weighted_massey_sum = massey_sum * weight
            if name in massey_dict: 
                massey_dict[name] += weighted_massey_sum
#                     massey_dict[name] += massey_sum
            else:
                massey_dict[name] = weighted_massey_sum

            if name in player_total:
                player_total[name] += total_matches * weight
            else:
                player_total[name] = total_matches * weight

            # add wins and losses to the player's total
#                 if name in player_wins:
#                     player_wins[name] += total_wins * weight
#                     player_losses[name] += total_losses * weight
#                 else: 
#                     player_wins[name] =  total_wins * weight
#                     player_losses[name] = total_losses * weight

            player_series = dict(zip(df.index, total_matches_arr*weight))

            if name in player_dict:
                player_dict[name] = add_dicts(player_series, player_dict[name])
            else:
                player_dict[name] = player_series
massey_A = pd.DataFrame(player_dict)
# massey_A = pd.DataFrame(player_dict)
# tournement_dfs.append(d)
massey_A = massey_A.reindex(massey_A.columns).fillna(0)*-1
# Out:
# 2013
# 2014
# 2015
# 2012
# 2017
# 2010
# 2019
# 2020
# 2018
# 2011
# 2016

# %%
massey_A = pd.DataFrame(player_dict)
massey_A = massey_A.reindex(massey_A.columns).fillna(0)*-1

# %%
massey = pd.Series(massey_dict)
rhv = []
for name in massey_A.index:
    score = massey.loc[name] 
#     v.append(massey[name])
    rhv.append(score)
    # set the diagonal
    player_sum = massey_A.loc[:,name].sum()
    massey_A.loc[name, name] =-1* player_sum
# rhv[-1] = 0
rhv = np.array(rhv)

# %%
massey_A.to_csv('test_massey.csv')

# %%
massey_A.iloc[-1] = [1]*len(massey_A.columns)

# %%
rhv[-1] = 0

# %%
massey.to_csv('rhv.csv')
# Out:
# /Users/chrisamoroso/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
x = scipy.linalg.lstsq(massey_A.values, rhv)
ratings = pd.DataFrame({'player' : massey_A.index, 'rating' : x[0]}).set_index('player')
ratings = ratings.sort_values('rating', ascending=False)

# %%
ratings.head(50)
# Out:
#                            rating
# player
# Rory McIlroy             4.528093
# Jon Rahm                 4.432874
# Dustin Johnson           4.417170
# Armando Favela           4.298809
# Justin Rose              4.220091
# Ignacio Garrido          4.194928
# Robert MacIntyre         4.159393
# Jason Day                4.122193
# Hideki Matsuyama         4.095035
# Patrick Cantlay          4.087429
# Jordan Spieth            4.043271
# Brooks Koepka            4.006700
# Tommy Fleetwood          3.996061
# Henrik Stenson           3.989914
# Justin Thomas            3.989666
# John Cook                3.960657
# Angelo Que               3.952494
# Rickie Fowler            3.943145
# Adam Scott               3.925074
# Victor Perez             3.901117
# Eduardo De La Riva       3.899739
# Erik van Rooyen          3.892261
# Collin Morikawa          3.883784
# Paul Casey               3.876442
# Matt Kuchar              3.827514
# Gregory Yates            3.780808
# Daisuke Kataoka          3.757913
# Sungjae Im               3.756204
# Richard Bland            3.755784
# Scottie Scheffler        3.740056
# Tiger Woods              3.698474
# Sergio Garcia            3.697619
# Phil Mickelson           3.695194
# Chad Ramey               3.694505
# Webb Simpson             3.690575
# Tony Finau               3.680753
# Christiaan Bezuidenhout  3.642725
# Tyrrell Hatton           3.637728
# Patrick Reed             3.622156
# Johan Edfors             3.621534
# Bryson DeChambeau        3.583426
# Carl Yuan                3.580807
# Callum Shinkwin          3.568200
# Louis Oosthuizen         3.563913
# Xander Schauffele        3.549027
# Jim Furyk                3.514169
# Andrew Wilson            3.504098
# Steve Stricker           3.490247
# Jimmy Gunn               3.462242
# Francesco Molinari       3.458530

# %% [markdown]
# #### Build the right hand vector and the diagonal in the Massey matrix

# %%
for name in massey_A.index:
    row = massey_A.loc[:,name].values
    col = massey_A.loc[name,:].values
    if (row - col).sum():
        print((row-col).sum())
        print(row)
        print(col)
        break
# Out:
# 1.0
# [ 4.17177374e+04 -1.99549565e+02 -1.57662905e+02 ... -1.46111487e+00
#  -1.46111487e+00  1.00000000e+00]
# [ 4.17177374e+04 -1.99549565e+02 -1.57662905e+02 ... -1.46111487e+00
#  -1.46111487e+00 -0.00000000e+00]

# %% [markdown]
# ## Solve Matrix

# %%
v = v.astype(int)
v[-1] = 0

# %%
massey_A.shape, v.size
# Out:
# ((1755, 1755), 1755)

# %%
import scipy

# %%
len(x)
# Out:
# 4

# %%
massey_A.values.size, x
# Out:
# (4000000, (array([10.42534068, 11.31160527,  9.7749072 , ...,  3.91849781,
#          -6.24843168, -6.24836302]),
#   array([], dtype=float64),
#   1899,
#   array([6.15004852e+04, 5.98481923e+04, 5.67431548e+04, ...,
#          9.49593201e-14, 7.43944807e-14, 5.64401111e-14])))

# %%
x
# Out:
# (array([10.42534068, 11.31160527,  9.7749072 , ...,  3.91849781,
#         -6.24843168, -6.24836302]),
#  array([], dtype=float64),
#  1899,
#  array([6.15004852e+04, 5.98481923e+04, 5.67431548e+04, ...,
#         9.49593201e-14, 7.43944807e-14, 5.64401111e-14]))

# %%
ratings.head(10)
# Out:
#                         rating
# player
# Lee Bedford       5.323249e+12
# Bhavik Patel      8.277918e+11
# Siddikur Rahman   4.184188e+11
# Paul Chaplet      3.325038e+05
# Jin Cheng         1.539842e+03
# Derek Bard        1.496489e+03
# Ian Woosnam       3.947149e+02
# Romain Langasque  3.060550e+02
# Larry Mize        2.712728e+02
# Victor Dubuisson  7.873871e+01

# %%
roster = pd.read_csv('2020_players.csv', header=None)
roster.head()
roster = roster[1].values

# %%
ranks = ratings.loc[roster].sort_values('rating', ascending=False)

# %%
ranks.head(40)
# Out:
#                            rating
# player
# Rory McIlroy             4.528093
# Jon Rahm                 4.432874
# Dustin Johnson           4.417170
# Justin Rose              4.220091
# Jason Day                4.122193
# Hideki Matsuyama         4.095035
# Patrick Cantlay          4.087429
# Jordan Spieth            4.043271
# Brooks Koepka            4.006700
# Tommy Fleetwood          3.996061
# Henrik Stenson           3.989914
# Justin Thomas            3.989666
# Rickie Fowler            3.943145
# Adam Scott               3.925074
# Victor Perez             3.901117
# Erik van Rooyen          3.892261
# Collin Morikawa          3.883784
# Paul Casey               3.876442
# Matt Kuchar              3.827514
# Sungjae Im               3.756204
# Scottie Scheffler        3.740056
# Tiger Woods              3.698474
# Sergio Garcia            3.697619
# Phil Mickelson           3.695194
# Webb Simpson             3.690575
# Tony Finau               3.680753
# Christiaan Bezuidenhout  3.642725
# Tyrrell Hatton           3.637728
# Patrick Reed             3.622156
# Bryson DeChambeau        3.583426
# Louis Oosthuizen         3.563913
# Xander Schauffele        3.549027
# Francesco Molinari       3.458530
# Bubba Watson             3.453926
# Marc Leishman            3.448176
# Gary Woodland            3.443166
# Zach Johnson             3.414707
# Brandt Snedeker          3.334740
# Kevin Na                 3.325084
# Shane Lowry              3.298632

# %% [markdown]
# ## Model Validation with one Touenement

# %%
df.head()
# Out:
#                   POS TO PAR    R1    R2    R3    R4  TOT    EARNINGS  \
# PLAYER
# Branden Grace       1     -9  66.0  74.0  69.0  66.0  275  $1,062,000
# Russell Knox       T2     -7  72.0  65.0  73.0  67.0  277    $519,200
# Luke Donald        T2     -7  66.0  71.0  69.0  71.0  277    $519,200
# Bryson DeChambeau  T4     -5  70.0  69.0  72.0  68.0  279    $259,600
# Kevin Na           T4     -5  73.0  71.0  66.0  69.0  279    $259,600
#
#                    FEDEX PTS              name_arr   pro  finished
# PLAYER
# Branden Grace            500      [Branden, Grace]  True      True
# Russell Knox             245       [Russell, Knox]  True      True
# Luke Donald              245        [Luke, Donald]  True      True
# Bryson DeChambeau          0  [Bryson, DeChambeau]  True      True
# Kevin Na                 123           [Kevin, Na]  True      True

# %%
massey_A = massey_A*-1
massey_A = massey_A.fillna(0)
massey_A = pd.DataFrame(player_dict)
massey_A = massey_A.reindex(massey_A.columns).fillna(0)

# %%
massey_A.head()
# Out:
#                 Jason Dufner  Jim Furyk  Henrik Stenson  Jonas Blixt  \
# Jason Dufner             0.0      368.0           264.0        267.0
# Jim Furyk              368.0        0.0           246.0        194.0
# Henrik Stenson         264.0      246.0             0.0        138.0
# Jonas Blixt            267.0      194.0           138.0          0.0
# Adam Scott             358.0      353.0           274.0        149.0
#
#                 Adam Scott  Scott Piercy  David Toms  Dustin Johnson  \
# Jason Dufner         358.0         394.0       231.0           370.0
# Jim Furyk            353.0         312.0       181.0           374.0
# Henrik Stenson       274.0         194.0       110.0           290.0
# Jonas Blixt          149.0         263.0       107.0           171.0
# Adam Scott             0.0         283.0       136.0           402.0
#
#                 Jason Day  Rory McIlroy  ...  Robby Ormand  Julien Brun  \
# Jason Dufner        371.0         281.0  ...           0.0          0.0
# Jim Furyk           350.0         266.0  ...           0.0          0.0
# Henrik Stenson      280.0         292.0  ...           0.0          0.0
# Jonas Blixt         182.0         127.0  ...           0.0          0.0
# Adam Scott          391.0         378.0  ...           0.0          0.0
#
#                 Gregory Yates  Jorge Fernandez-Valdes  Frankie Capan  \
# Jason Dufner              4.0                     0.0            0.0
# Jim Furyk                 0.0                     0.0            0.0
# Henrik Stenson            4.0                     0.0            0.0
# Jonas Blixt               4.0                     0.0            0.0
# Adam Scott                0.0                     0.0            0.0
#
#                 Wil Bateman  Nacho Elvira  Yoshio Yamamoto  Sammy Schmitz  \
# Jason Dufner            0.0           2.0              2.0            2.0
# Jim Furyk               0.0           0.0              0.0            0.0
# Henrik Stenson          0.0           0.0              0.0            2.0
# Jonas Blixt             0.0           2.0              2.0            0.0
# Adam Scott              0.0           0.0              0.0            2.0
#
#                 Paul Chaplet
# Jason Dufner             2.0
# Jim Furyk                0.0
# Henrik Stenson           2.0
# Jonas Blixt              0.0
# Adam Scott               2.0
#
# [5 rows x 2000 columns]

# %%
massey_A.tail()
# Out:
#                  Jason Dufner  Jim Furyk  Henrik Stenson  Jonas Blixt  \
# Wil Bateman               0.0        0.0             0.0          0.0
# Nacho Elvira              2.0        0.0             0.0          2.0
# Yoshio Yamamoto           2.0        0.0             0.0          2.0
# Sammy Schmitz             2.0        0.0             2.0          0.0
# Paul Chaplet              2.0        0.0             2.0          0.0
#
#                  Adam Scott  Scott Piercy  David Toms  Dustin Johnson  \
# Wil Bateman             0.0           0.0         2.0             0.0
# Nacho Elvira            0.0           0.0         0.0             0.0
# Yoshio Yamamoto         0.0           0.0         0.0             0.0
# Sammy Schmitz           2.0           2.0         0.0             2.0
# Paul Chaplet            2.0           2.0         0.0             2.0
#
#                  Jason Day  Rory McIlroy  ...  Robby Ormand  Julien Brun  \
# Wil Bateman            0.0           0.0  ...           0.0          0.0
# Nacho Elvira           0.0           0.0  ...           0.0          0.0
# Yoshio Yamamoto        0.0           0.0  ...           0.0          0.0
# Sammy Schmitz          2.0           2.0  ...           0.0          0.0
# Paul Chaplet           2.0           2.0  ...           0.0          0.0
#
#                  Gregory Yates  Jorge Fernandez-Valdes  Frankie Capan  \
# Wil Bateman                0.0                     2.0            2.0
# Nacho Elvira               0.0                     0.0            0.0
# Yoshio Yamamoto            0.0                     0.0            0.0
# Sammy Schmitz              0.0                     0.0            0.0
# Paul Chaplet               0.0                     0.0            0.0
#
#                  Wil Bateman  Nacho Elvira  Yoshio Yamamoto  Sammy Schmitz  \
# Wil Bateman              0.0           0.0              0.0            0.0
# Nacho Elvira             0.0           0.0              2.0            0.0
# Yoshio Yamamoto          0.0           2.0              0.0            0.0
# Sammy Schmitz            0.0           0.0              0.0            0.0
# Paul Chaplet             0.0           0.0              0.0            2.0
#
#                  Paul Chaplet
# Wil Bateman               0.0
# Nacho Elvira              0.0
# Yoshio Yamamoto           0.0
# Sammy Schmitz             2.0
# Paul Chaplet              0.0
#
# [5 rows x 2000 columns]

# %%
massey = pd.Series(massey_dict)
v = []
for name in massey_A.index:
    score = massey.loc[name] 
#     v.append(massey[name])
    v.append(score)
    # set the diagonal
    massey_A.loc[name, name] = player_wins[name] + player_losses[name]
v = np.array(v)

# %%
x =  np.linalg.solve(massey_A.values, v)
ratings = pd.DataFrame({'player' : massey_A.index.values, 'rating' : x}).set_index('player')
ratings = ratings.sort_values('rating', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-416-b86a03fe843c> in <module>
# ----> 1 x =  np.linalg.solve(massey_A.values, v)
#       2 ratings = pd.DataFrame({'player' : massey_A.index.values, 'rating' : x}).set_index('player')
#       3 ratings = ratings.sort_values('rating', ascending=False)
#
# ~/Library/Python/3.7/lib/python/site-packages/numpy/linalg/linalg.py in solve(a, b)
#     401     signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     402     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 403     r = gufunc(a, b, signature=signature, extobj=extobj)
#     404
#     405     return wrap(r.astype(result_t, copy=False))
#
# ~/Library/Python/3.7/lib/python/site-packages/numpy/linalg/linalg.py in _raise_linalgerror_singular(err, flag)
#      95
#      96 def _raise_linalgerror_singular(err, flag):
# ---> 97     raise LinAlgError("Singular matrix")
#      98
#      99 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %%
ratings.head(20)
# Out:
#                    rating
# player
# Jason Dufner     2.622666
# Jim Furyk        2.264105
# Henrik Stenson   2.084825
# Adam Scott       2.000457
# Jonas Blixt      1.631351
# Matt Kuchar      1.561045
# Steve Stricker   1.554014
# Scott Piercy     1.543468
# Roberto Castro   1.371218
# Jason Day        1.367703
# Robert Garrigus  1.290366
# Zach Johnson     1.276305
# David Toms       1.272790
# Justin Rose      1.205999
# Webb Simpson     1.198968
# Rickie Fowler    1.191938
# Graeme McDowell  1.188423
# Rory McIlroy     1.184907
# David Lynn       1.104055
# Marc Leishman    1.097025

# %%
df.head(20)
# Out:
#                   POS TO PAR    R1    R2    R3    R4  TOT    EARNINGS  \
# PLAYER
# Jason Dufner        1    -10  68.0  63.0  71.0  68.0  270  $1,445,000
# Jim Furyk           2     -8  65.0  68.0  68.0  71.0  272    $865,000
# Henrik Stenson      3     -7  68.0  66.0  69.0  70.0  273    $545,000
# Jonas Blixt         4     -6  68.0  70.0  66.0  70.0  274    $385,000
# Adam Scott         T5     -5  65.0  68.0  72.0  70.0  275    $304,000
# Scott Piercy       T5     -5  67.0  71.0  72.0  65.0  275    $304,000
# David Toms          7     -4  71.0  69.0  69.0  67.0  276    $259,000
# Dustin Johnson     T8     -3  72.0  71.0  65.0  69.0  277    $206,250
# Jason Day          T8     -3  67.0  71.0  72.0  67.0  277    $206,250
# Rory McIlroy       T8     -3  69.0  71.0  67.0  70.0  277    $206,250
# Zach Johnson       T8     -3  69.0  70.0  70.0  68.0  277    $206,250
# Marc Leishman     T12     -2  70.0  70.0  70.0  68.0  278  $132,785.7
# Steve Stricker    T12     -2  68.0  67.0  70.0  73.0  278  $132,785.7
# Graeme McDowell   T12     -2  70.0  69.0  73.0  66.0  278  $132,785.7
# Kevin Streelman   T12     -2  70.0  72.0  66.0  70.0  278  $132,785.7
# Roberto Castro    T12     -2  68.0  69.0  71.0  70.0  278  $132,785.7
# Boo Weekley       T12     -2  72.0  69.0  70.0  67.0  278  $132,785.7
# Marc Warren       T12     -2  74.0  67.0  68.0  69.0  278  $132,785.7
# Hideki Matsuyama  T19     -1  72.0  68.0  73.0  66.0  279  $93,166.66
# Rickie Fowler     T19     -1  70.0  68.0  72.0  69.0  279  $93,166.66
#
#                   FEDEX PTS             name_arr   pro  finished
# PLAYER
# Jason Dufner            600      [Jason, Dufner]  True      True
# Jim Furyk               330         [Jim, Furyk]  True      True
# Henrik Stenson          210    [Henrik, Stenson]  True      True
# Jonas Blixt             150       [Jonas, Blixt]  True      True
# Adam Scott              115        [Adam, Scott]  True      True
# Scott Piercy            115      [Scott, Piercy]  True      True
# David Toms              100        [David, Toms]  True      True
# Dustin Johnson           85    [Dustin, Johnson]  True      True
# Jason Day                85         [Jason, Day]  True      True
# Rory McIlroy             85      [Rory, McIlroy]  True      True
# Zach Johnson             85      [Zach, Johnson]  True      True
# Marc Leishman            62     [Marc, Leishman]  True      True
# Steve Stricker           62    [Steve, Stricker]  True      True
# Graeme McDowell          62   [Graeme, McDowell]  True      True
# Kevin Streelman          62   [Kevin, Streelman]  True      True
# Roberto Castro           62    [Roberto, Castro]  True      True
# Boo Weekley              62       [Boo, Weekley]  True      True
# Marc Warren               0       [Marc, Warren]  True      True
# Hideki Matsuyama          0  [Hideki, Matsuyama]  True      True
# Rickie Fowler            51     [Rickie, Fowler]  True      True

# %%
df.loc['Matt Kuchar']
# Out:
# POS                     T22
# TO PAR                    E
# R1                       67
# R2                       66
# R3                       76
# R4                       71
# TOT                     280
# EARNINGS            $75,000
# FEDEX PTS                48
# name_arr     [Matt, Kuchar]
# pro                    True
# finished               True
# Name: Matt Kuchar, dtype: object
