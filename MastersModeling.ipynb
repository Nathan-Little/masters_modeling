# %% [markdown]
# # Data Scraping from ESPN
#
# tournements: https://www.espn.com/golf/schedule/_/tour/pga

# %% [markdown]
# ### Load the roster for the 2020 Masters from masters.com

# %%
roster = pd.read_excel('players.xlsx')

# %%
roster.head()
# Out:
#                          Name        Country Qualification
# 0              An, Byeong Hun          Korea         18,19
# 1            # Ancer, Abraham         Mexico      17,18,19
# 2         #* Augenstein, John  United States           7-B
# 3  # Bezuidenhout, Christiaan   South Africa            19
# 4              Cabrera, Angel      Argentina             1

# %%
s = pd.Series(players_2020)

# %%
roster = pd.read_csv('2020_players.csv', header=None)
roster.head()
roster = roster[1].values
roster
# Out:
# array(['Byeong-Hun An', 'Abraham Ancer', 'Christiaan Bezuidenhout',
#        'Angel Cabrera', 'Rafael Cabrera Bello', 'Patrick Cantlay',
#        'Paul Casey', 'Cameron Champ', 'Corey Conners', 'Fred Couples',
#        'Jason Day', 'Bryson DeChambeau', 'Tyler Duncan', 'Tony Finau',
#        'Matthew Fitzpatrick', 'Tommy Fleetwood', 'Rickie Fowler',
#        'Dylan Frittelli', 'Sergio Garcia', 'Lucas Glover',
#        'Lanto Griffin', 'Adam Hadwin', 'Justin Harding', 'Tyrrell Hatton',
#        'Max Homa', 'Billy Horschel', 'Charles Howell III', 'Sungjae Im',
#        'Shugo Imahira', 'Trevor Immelman', 'Jazz Janewattananond',
#        'Dustin Johnson', 'Zach Johnson', 'Sung Kang', 'Si Woo Kim',
#        'Kevin Kisner', 'Brooks Koepka', 'Jason Kokrak', 'Matt Kuchar',
#        'Andrew Landry', 'Bernhard Langer', 'Nate Lashley',
#        'Marc Leishman', 'Shane Lowry', 'Sandy Lyle', 'Hideki Matsuyama',
#        'Graeme McDowell', 'Rory McIlroy', 'Phil Mickelson', 'Larry Mize',
#        'Francesco Molinari', 'Collin Morikawa', 'Sebastian Munoz',
#        'Kevin Na', 'Joaquin Niemann', 'Jose Maria Olazabal',
#        'Louis Oosthuizen', 'C.T. Pan', 'Victor Perez', 'J.T. Poston',
#        'Ian Poulter', 'Andrew Putnam', 'Jon Rahm', 'Chez Reavie',
#        'Patrick Reed', 'Justin Rose', 'Xander Schauffele',
#        'Scottie Scheffler', 'Charl Schwartzel', 'Adam Scott',
#        'Webb Simpson', 'Vijay Singh', 'Cameron Smith', 'Brandt Snedeker',
#        'Jordan Spieth', 'Henrik Stenson', 'Nick Taylor', 'Justin Thomas',
#        'Brendon Todd', 'Erik van Rooyen', 'Jimmy Walker', 'Matt Wallace',
#        'Bubba Watson', 'Mike Weir', 'Lee Westwood', 'Bernd Wiesberger',
#        'Danny Willett', 'Matthew Wolff', 'Gary Woodland', 'Tiger Woods'],
#       dtype=object)

# %%
s.to_csv('2020_players.csv')
# Out:
# /Users/chrisamoroso/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Scraping previous tournement data from

# %%
base_link = "https://www.espn.com/golf/schedule/_/season/"
main_links = [
    'https://www.espn.com/golf/schedule/_/season/2010',
    'https://www.espn.com/golf/schedule/_/season/2011',
    'https://www.espn.com/golf/schedule/_/season/2012',
    'https://www.espn.com/golf/schedule/_/season/2013',
    'https://www.espn.com/golf/schedule/_/season/2014',
    'https://www.espn.com/golf/schedule/_/season/2015',
    'https://www.espn.com/golf/schedule/_/season/2016',
    'https://www.espn.com/golf/schedule/_/season/2017',
    'https://www.espn.com/golf/schedule/_/season/2018', 
    'https://www.espn.com/golf/schedule/_/season/2019',
    'https://www.espn.com/golf/schedule/_/season/2020'
]

# %% [markdown]
# ### Get links to all of the tournements in the past 10 years

# %%
tournement_links = {}
for link in main_links:
    year = link.split('/')[-1]
    tournement_links[year] = []
    source = urllib.request.urlopen(link).read()
    soup = BeautifulSoup(source,'lxml')
    table_titles = soup.findAll("section", {"class" : "ResponsiveTable"})
    for table in table_titles:
        title = table.find("div", {"class" : "Table__Title"})
        if title.text == "Completed Tournaments":
            # This is the one that we want
            # Still saved in table
            break
    links = table.findAll('a', {'class' : "AnchorLink"})
    for link in links: 
        href = link.attrs['href']
        if "player" not in href.split('/'):
            tournement_links[year].append(href)

# %% [markdown]
# ### Extract all tournement links from the table
#
# There are tournement links and player links. Tournement links do not have "player" in the path.

# %%
def get_tournement_results(link):
    source = urllib.request.urlopen(link).read()
    soup = BeautifulSoup(source,'lxml')
    
    compet_table = soup.find("div", {"class" : "competitors"})
    tables = compet_table.find_all("section", {"class" : "ResponsiveTable"})
    for table in tables:
        #Get headings
        headings = []
        headings_tag = table.find('thead')
        head_cells = headings_tag.findAll("th")
        if len(head_cells) < 8: 
            continue

        for heading in headings_tag.findAll("th"):
                headings.append(heading.find('a').text)
        
        body = table.find("tbody")
        rows = body.findAll('tr')
        player_data = []
        for row in rows:
            current_row = []
            for text in row.findAll("td"):
                current_row.append(text.text)

            player_data.append(current_row)
        return [headings] + player_data

# %%
data = {}
for year in tournement_links:
    for link in tournement_links[year]:
        data[year] = []
        try:
            results = get_tournement_results(link)
    #         data.append(parse_results(results))

    #         df = pd.DataFrame(results, columns=['positon', 'name','score', 'r1', 'r2', 'r3','r4', 'total', 'winnings', 'x']).set_index('name')
            df = pd.DataFrame(results[1:], columns=results[0]).set_index("PLAYER") 
            df[['R1', 'R2', 'R3', 'R4']] = df[['R1', 'R2', 'R3', 'R4']].replace("--", np.nan).astype(float)
            # Set types
            df.to_csv('data/' + str(year) + '/' + link.split('=')[-1])
            data[year].append(df)

        except Exception as err: 
            print(link)
            print(err)
# Out:
# http://www.espn.com/golf/leaderboard?tournamentId=769
# [Errno 54] Connection reset by peer
# http://www.espn.com/golf/leaderboard?tournamentId=802
# 'NoneType' object has no attribute 'find_all'
# http://www.espn.com/golf/leaderboard?tournamentId=401024025
# 'NoneType' object has no attribute 'find_all'
# http://www.espn.com/golf/leaderboard?tournamentId=838
# 'NoneType' object has no attribute 'find_all'
# http://www.espn.com/golf/leaderboard?tournamentId=919
# 'NoneType' object has no attribute 'find_all'
# http://www.espn.com/golf/leaderboard?tournamentId=984
# "['R4'] not in index"
# http://www.espn.com/golf/leaderboard?tournamentId=993
# 'NoneType' object has no attribute 'find_all'
# http://www.espn.com/golf/leaderboard?tournamentId=1025
# 'NoneType' object has no attribute 'find_all'
# http://www.espn.com/golf/leaderboard?tournamentId=1026
# 'NoneType' object has no attribute 'find_all'
# http://www.espn.com/golf/leaderboard?tournamentId=1062
# 'NoneType' object has no attribute 'find_all'
# http://www.espn.com/golf/leaderboard?tournamentId=1181
# "['R4'] not in index"
# http://www.espn.com/golf/leaderboard?tournamentId=1213
# 'NoneType' object has no attribute 'find_all'
# http://www.espn.com/golf/leaderboard?tournamentId=1214
# 'NoneType' object has no attribute 'find_all'
# http://www.espn.com/golf/leaderboard?tournamentId=1272
# 'NoneType' object has no attribute 'find_all'
# http://www.espn.com/golf/leaderboard?tournamentId=2264
# 'NoneType' object has no attribute 'find_all'
# http://www.espn.com/golf/leaderboard?tournamentId=2277
# 'NoneType' object is not subscriptable
# http://www.espn.com/golf/leaderboard?tournamentId=2265
# 'NoneType' object has no attribute 'find_all'
# http://www.espn.com/golf/leaderboard?tournamentId=2259
# 'NoneType' object has no attribute 'find_all'
# http://www.espn.com/golf/leaderboard?tournamentId=2516
# 'NoneType' object has no attribute 'find_all'
# http://www.espn.com/golf/leaderboard?tournamentId=2491
# "['R4'] not in index"

# %% [markdown]
# Remove all of the amateurs and people who withdrew or were disqualified from the dataset.
#
# When a player withdraws, they get a score of whatever they had when they withdrew—42 through 9 holes, for example— so it looks like the got a 42 on the round and beat everybody.

# %% [markdown]
# # Data Preprocessing
# ### Parse results from each tournement

# %%
import os

dfs = {}
for folder in os.listdir('data'):
    if folder[0] == '2':
        dfs[folder] = []
        for file in os.listdir('data/' + folder):
            dfs[folder].append(pd.read_csv('data/' + folder + '/' +file).set_index("PLAYER"))

# %%
pro_data = {}
for year in dfs: 
    pro_data[year] = []
    for df in dfs[year]:
        split_names = [] 
        for player in df.index: 
            split_names.append(player.split(' '))
        df['name_arr'] = split_names 
        df['pro'] = df['name_arr'].apply(lambda arr : arr[-1] != '(a)')
        df = df[df.pro]
        df['finished'] = df['TO PAR'].apply(lambda s : s != "WD" and s != "DQ")
        df = df[df.finished]
        pro_data[year].append(df)
# Out:
# /Users/chrisamoroso/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# Reduce the dataframe to only the players that are in the masters in 2020

# %% [markdown]
# Pro data is a list of dataframes where each dataframe is a single tournement. The indexes are the player names and the columns are the scores in each round

# %%
pd.isnull([np.nan, 0])
# Out:
# array([ True, False])

# %%
def add_dicts(s1, s2):
    '''Function that adds the values of two pandas series'''
    result = {}
    for name in s1:
        if name in s2: 
            result[name] = s1[name] + s2[name]
        else: 
            result[name] = s1[name]
            
    for name in s2: 
        if name not in s1:
            result[name] = s2[name]
    return result

# %% [markdown]
# ### Build the Massey Matrix

# %%
tounement_dfs = []
player_dict = {} # key : name, value : np array where true = win, false = loss, rows are rounds, index is other player
player_wins = {}
player_losses = {}
massey_dict = {}
columns = []
rows = []
for year in dfs:
    for df in dfs[year]:
        # 4 X num players matrix (numpy)
        all_rounds = df[['R1', 'R2', 'R3', 'R4']].values.T
    #     print(all_rounds)
        rows = []
        for i, name in enumerate(df.index): 
                player_rounds = df.loc[name, ['R1', 'R2', 'R3', 'R4']].values
                try:
                    player_rounds = player_rounds.reshape(4, 1)
                except: 
                    player_rounds = player_rounds[0].reshape(4, 1)

                #difference between scores per round
                diff = all_rounds - player_rounds                
                where_are_NaNs = pd.isnull(diff)
                diff[where_are_NaNs] = 0
        #         print(diff)
                wins = diff > 0 & (pd.notnull(diff))
        #         print(wins)
                total_matches_arr = pd.notnull(diff).sum(axis=0) 
        #         print(total_matches_arr)
                total_matches_arr[i] = 0
                total_matches = total_matches_arr.sum()
                total_wins = wins.sum()
                total_losses = total_matches - total_wins

                    #massey method 
#                 massey_diff = massey_diff.fillna()
#                 massey_sum =  massey_diff.values.sum()
#                 massey_sum =  massey_diff.sum()
                massey_sum = diff.sum()
                if name in massey_dict: 
                    massey_dict[name] += massey_sum 
                else:
                    massey_dict[name] = massey_sum

                # add wins and losses to the player's total
                if name in player_wins:
                    player_wins[name] += total_wins
                    player_losses[name] += total_losses
                else: 
                    player_wins[name] = total_wins
                    player_losses[name] = total_losses

#                 player_series = pd.DataFrame({"player" : df.index, "games" : total_matches_arr}).fillna(0).reset_index()
                player_series = dict(zip(df.index, total_matches_arr))
                
#                 if name in player_dict:
#                     player_dict[name] = player_series.groupby('player').sum().add(player_dict[name].groupby('player').sum(), fill_value=0).reset_index()
#                 else: 
#                     player_dict[name] = player_series
                    
                if name in player_dict: 
                    player_dict[name] = add_dicts(player_series, player_dict[name])
                else:
                    player_dict[name] = player_series

# massey_A = pd.DataFrame(player_dict)
# tournement_dfs.append(d)
# massey_A = massey_A.reindex(massey_A.columns)

# %% [markdown]
# Combine all of the players

# %% [markdown]
# #### Ensure that the columns are in the same order as the rows

# %%
for name in massey_A.index:
    row = massey_A.loc[:,name].values
    col = massey_A.loc[name,:].values
    if (row != col).sum() != 0:
#         print(name)
        pass

# %%
massey_A = pd.DataFrame(player_dict)
massey_A = massey_A.reindex(massey_A.columns).fillna(0)
massey_A.head()
# Out:
#                 Jason Dufner  Jim Furyk  Henrik Stenson  Jonas Blixt  \
# Jason Dufner             0.0      460.0           344.0        360.0
# Jim Furyk              460.0        0.0           332.0        264.0
# Henrik Stenson         344.0      332.0             0.0        200.0
# Jonas Blixt            360.0      264.0           200.0          0.0
# Adam Scott             436.0      432.0           336.0        204.0
#
#                 Adam Scott  Scott Piercy  David Toms  Dustin Johnson  \
# Jason Dufner         436.0         528.0       304.0           452.0
# Jim Furyk            432.0         436.0       244.0           464.0
# Henrik Stenson       336.0         280.0       176.0           340.0
# Jonas Blixt          204.0         380.0       172.0           240.0
# Adam Scott             0.0         376.0       184.0           452.0
#
#                 Jason Day  Rory McIlroy  ...  Julien Brun  Gregory Yates  \
# Jason Dufner        456.0         348.0  ...          0.0            4.0
# Jim Furyk           444.0         352.0  ...          0.0            0.0
# Henrik Stenson      340.0         364.0  ...          0.0            4.0
# Jonas Blixt         240.0         172.0  ...          0.0            4.0
# Adam Scott          456.0         436.0  ...          0.0            0.0
#
#                 Jorge Fernandez-Valdes  Frankie Capan  Wil Bateman  \
# Jason Dufner                       0.0            0.0          0.0
# Jim Furyk                          0.0            0.0          0.0
# Henrik Stenson                     0.0            0.0          0.0
# Jonas Blixt                        0.0            0.0          0.0
# Adam Scott                         0.0            0.0          0.0
#
#                 Nacho Elvira  Yoshio Yamamoto  Sammy Schmitz  Jin Cheng  \
# Jason Dufner             4.0              4.0            4.0        4.0
# Jim Furyk                0.0              0.0            0.0        0.0
# Henrik Stenson           0.0              0.0            4.0        4.0
# Jonas Blixt              4.0              4.0            0.0        0.0
# Adam Scott               0.0              0.0            4.0        4.0
#
#                 Paul Chaplet
# Jason Dufner             4.0
# Jim Furyk                0.0
# Henrik Stenson           4.0
# Jonas Blixt              0.0
# Adam Scott               4.0
#
# [5 rows x 2049 columns]

# %%
massey_A.shape
# Out:
# (2049, 2049)

# %%
player_dict['Tiger Woods']
# Out:
# {'Charl Schwartzel': 240,
#  'Adam Scott': 300,
#  'Jason Day': 312,
#  'Tiger Woods': 0,
#  'Luke Donald': 216,
#  'Geoff Ogilvy': 208,
#  'Angel Cabrera': 176,
#  'Bo Van Pelt': 212,
#  'K.J. Choi': 220,
#  'Ryan Palmer': 208,
#  'Lee Westwood': 184,
#  'Steve Stricker': 208,
#  'Edoardo Molinari': 56,
#  'Justin Rose': 328,
#  'Ross Fisher': 112,
#  'Brandt Snedeker': 284,
#  'Rory McIlroy': 304,
#  'Trevor Immelman': 140,
#  'Fred Couples': 48,
#  'Martin Laird': 260,
#  'Ryo Ishikawa': 136,
#  'Y.E. Yang': 148,
#  'Ricky Barnes': 148,
#  'David Toms': 136,
#  'Jim Furyk': 288,
#  'Gary Woodland': 264,
#  'Matt Kuchar': 300,
#  'Robert Karlsson': 92,
#  'Charley Hoffman': 256,
#  'Ian Poulter': 272,
#  'Hideki Matsuyama': 192,
#  'Miguel Angel Jimenez': 92,
#  'Phil Mickelson': 332,
#  'Alvaro Quiros': 80,
#  'Alex Cejka': 120,
#  'Sergio Garcia': 228,
#  'Ryan Moore': 284,
#  'Dustin Johnson': 324,
#  'Rickie Fowler': 356,
#  'Bubba Watson': 312,
#  'Paul Casey': 232,
#  'Bill Haas': 284,
#  'Steve Marino': 88,
#  'Jeff Overton': 160,
#  'Kyung Kim': 60,
#  'Nick Watney': 312,
#  'Aaron Baddeley': 208,
#  'Ernie Els': 248,
#  'Camilo Villegas': 192,
#  "Sean O'Hair": 200,
#  'Tim Clark': 140,
#  'Hunter Mahan': 256,
#  'Francesco Molinari': 232,
#  'Robert Allenby': 160,
#  'Lucas Glover': 240,
#  'Zach Johnson': 284,
#  'Anthony Kim': 68,
#  'Stewart Cink': 256,
#  'Jerry Kelly': 100,
#  'Kevin Na': 248,
#  'Mark Wilson': 132,
#  'Graeme McDowell': 228,
#  'Stuart Appleby': 112,
#  'David Chung': 4,
#  'Heath Slocum': 108,
#  'Carl Pettersson': 188,
#  'Retief Goosen': 152,
#  'Ben Crane': 188,
#  'D.A. Points': 228,
#  'Peter Hanson': 108,
#  'Lion Kim': 4,
#  'Jason Bohn': 112,
#  'Yuta Ikeda': 72,
#  'Jhonattan Vegas': 176,
#  'Anders Hansen': 52,
#  'Gregory Havret': 16,
#  'Hiroyuki Fujita': 64,
#  'Padraig Harrington': 188,
#  'Kevin Streelman': 244,
#  'Louis Oosthuizen': 252,
#  'Peter Uihlein': 80,
#  "Mark O'Meara": 40,
#  'Larry Mize': 28,
#  'Rory Sabbatini': 232,
#  'Jin Jeong': 8,
#  'Martin Kaymer': 196,
#  'Jose Maria Olazabal': 40,
#  'Jonathan Byrd': 128,
#  'Arjun Atwal': 72,
#  'Craig Stadler': 16,
#  'Tom Watson': 48,
#  'Nathan Smith': 12,
#  'Davis Love III': 144,
#  'Sandy Lyle': 48,
#  'Vijay Singh': 224,
#  'Ben Crenshaw': 20,
#  'Mike Weir': 108,
#  'Ian Woosnam': 28,
#  'Henrik Stenson': 236,
#  'Freddie Jacobson': 144,
#  'Keegan Bradley': 312,
#  'Scott Stallings': 192,
#  'Hennie Otto': 12,
#  'Simon Dyson': 56,
#  'Richard Green': 12,
#  'Matteo Manassero': 64,
#  'Brendan Steele': 184,
#  'Alexander Noren': 152,
#  'Harrison Frazar': 48,
#  'Thomas Bjorn': 68,
#  'Darren Clarke': 76,
#  'Jae-Bum Park': 12,
#  'Pablo Larrazabal': 32,
#  'Troy Matteson': 108,
#  'Marc Leishman': 308,
#  'Billy Mayfair': 52,
#  'Kevin Sutherland': 40,
#  'Charles Howell III': 276,
#  'David Duval': 80,
#  'Tom Gillis': 112,
#  'Joe Durant': 20,
#  'Spencer Levin': 116,
#  'Pat Perez': 220,
#  'Ben Martin': 80,
#  'Blake Adams': 88,
#  'Brandt Jobe': 60,
#  'Zack Miller': 16,
#  'Paul Stankowski': 12,
#  'Jimmy Walker': 256,
#  'Tim Herron': 76,
#  'Anthony Paolucci': 4,
#  'Garrett Willis': 36,
#  'Bill Lunde': 68,
#  'Chris Couch': 64,
#  'Richard S. Johnson': 36,
#  'Scott Gutschewski': 8,
#  'D.J. Brigman': 8,
#  'Martin Piller': 40,
#  'Brian Davis': 160,
#  'Hunter Haas': 44,
#  'Chris Kirk': 160,
#  'Kyle Stanley': 236,
#  'Matt Jones': 144,
#  'Sung Kang': 124,
#  'David Mathis': 52,
#  'Chez Reavie': 160,
#  'Charlie Wi': 120,
#  'Jamie Lovemark': 76,
#  'Jarrod Lyle': 28,
#  'Josh Teater': 112,
#  'J.B. Holmes': 248,
#  'John Daly': 52,
#  'J.J. Henry': 152,
#  'Fabian Gomez': 68,
#  'Michael Thompson': 184,
#  'Bobby Gates': 40,
#  'Tag Ridings': 24,
#  'Greg Chalmers': 164,
#  'Paul Goydos': 52,
#  'Alex Prugh': 64,
#  'Cameron Tringale': 168,
#  'Steven Bowditch': 60,
#  'Jason Gore': 36,
#  'Dean Wilson': 12,
#  'Nathan Green': 44,
#  'Kevin Chappell': 180,
#  'Boo Weekley': 148,
#  'Derek Lamely': 56,
#  'Chad Campbell': 132,
#  'Joseph Bramlett': 28,
#  'Michael Connell': 20,
#  'Len Mattiace': 4,
#  'Jim Herman': 64,
#  'Ben Curtis': 136,
#  'Nate Smith': 8,
#  'Andres Gonzales': 36,
#  'Chris DiMarco': 44,
#  'Alexandre Rocha': 20,
#  'Jim Renner': 24,
#  'Scott McCarron': 32,
#  'Jesper Parnevik': 12,
#  'Lee Janzen': 36,
#  'Brian Smock': 8,
#  'Michael Putnam': 40,
#  'Chris Riley': 32,
#  'John Senden': 208,
#  'Rocco Mediate': 52,
#  'James Driscoll': 76,
#  'Andres Romero': 116,
#  'Robert Garrigus': 176,
#  'Bio Kim': 12,
#  'Justin Hicks': 44,
#  'Matt Bettencourt': 76,
#  'Daniel Summerhays': 116,
#  'Webb Simpson': 268,
#  'Kevin Kisner': 148,
#  'Kent Jones': 16,
#  'Shane Bertsch': 20,
#  'Tommy Gainey': 96,
#  'Billy Horschel': 216,
#  'John Rollins': 88,
#  'William McGirt': 132,
#  'Ryuji Imada': 64,
#  'Chad Collins': 56,
#  'Scott Gordon': 8,
#  'Kevin Stadler': 112,
#  'Duffy Waldorf': 4,
#  'David Hearn': 116,
#  'Colt Knost': 84,
#  'Troy Merritt': 124,
#  'Peter Tomasulo': 8,
#  'Josh Anderson': 4,
#  'Chris Baryla': 8,
#  'Stephen Ames': 68,
#  'Jeff Hart': 4,
#  'Michael Bradley': 36,
#  'Will Strickler': 8,
#  'Kenny Perry': 76,
#  'Matt McQuillan': 12,
#  'Michael Sim': 44,
#  "Nick O'Hern": 52,
#  'Kris Blanks': 68,
#  'Shigeki Maruyama': 8,
#  'Rich Beem': 32,
#  'Joe Affrunti': 8,
#  'Jon Fiedler': 8,
#  'James Oh': 4,
#  'Bryce Molder': 132,
#  'Jason Dufner': 264,
#  'Brian Gay': 192,
#  'Chris Stroud': 164,
#  'Corey Pavin': 8,
#  'Scott Verplank': 76,
#  'Justin Leonard': 136,
#  'D.J. Trahan': 80,
#  'J.P. Hayes': 28,
#  'Shaun Micheel': 52,
#  'Tim Petrovic': 56,
#  'Cameron Beckman': 48,
#  'Vaughn Taylor': 128,
#  'Johnson Wagner': 132,
#  'Brendon de Jonge': 168,
#  'Thomas Aiken': 36,
#  'Marcus Fraser': 56,
#  'S.S.P. Chawrasia': 4,
#  'Seung-yul Noh': 128,
#  'Rhys Davies': 24,
#  'Peter Senior': 12,
#  'Briny Baird': 24,
#  'Bud Cauley': 132,
#  'Adam Hadwin': 136,
#  'Will MacKenzie': 24,
#  'Cameron Percy': 48,
#  'Rod Pampling': 108,
#  'Roland Thatcher': 28,
#  'John Merrick': 124,
#  'Tom Pernice Jr': 36,
#  'Woody Austin': 36,
#  'Erick Justesen': 8,
#  'Frank Lickliter II': 4,
#  'Steve Elkington': 28,
#  'Steve Flesch': 32,
#  'Scott Piercy': 216,
#  'Patrick Cantlay': 132,
#  'George McNeill': 116,
#  'Aron Price': 8,
#  'Patrick Reed': 196,
#  'Jeff Quinney': 16,
#  'Todd Hamilton': 28,
#  'Kevin Tway': 96,
#  'Jeff Maggert': 64,
#  'Fran Quinn': 8,
#  'Joe Ogilvie': 44,
#  'Erik Flores': 4,
#  'Mitch Lowe': 16,
#  'Bob Estes': 92,
#  'Chris Tidland': 12,
#  'John Ellis': 4,
#  'Matt Marshall': 4,
#  'Kirk Triplett': 4,
#  'Todd Fischer': 4,
#  'Michael Letzig': 24,
#  'Johan Edfors': 4,
#  'Mike Small': 16,
#  'Bob Sowards': 20,
#  'Tetsuji Hiratsuka': 16,
#  'Sean Dougherty': 8,
#  'Gregory Bourdy': 24,
#  'Steve Schneiter': 4,
#  'Mark Brooks': 16,
#  'David Horsey': 16,
#  'Jeff Coston': 8,
#  'Robert McClellan': 12,
#  'Raphael Jacquelin': 20,
#  'WC Liang': 12,
#  'Jamie Donaldson': 72,
#  'Mike Northern': 4,
#  'Stephen Gallacher': 52,
#  'Stuart Smith': 8,
#  'Larry Nelson': 4,
#  'Craig Stevens': 4,
#  'Brendan Jones': 28,
#  'Rob Moss': 8,
#  'Dan Olsen': 4,
#  'Fredrik Andersson Hed': 16,
#  'Faber Jamerson': 4,
#  'Brad Lardon': 4,
#  'David Hutsell': 12,
#  'Jerry Pate': 4,
#  'Jeff Sorenson': 8,
#  'Marty Jertson': 16,
#  'Danny Balin': 24,
#  'Todd Camplin': 4,
#  'Scott Erdmann': 4,
#  'Brian Cairns': 12,
#  'Sam Saunders': 88,
#  'Dicky Pride': 44,
#  'Daniel Chopra': 36,
#  'Erik Compton': 100,
#  'Robert Damron': 8,
#  'Billy Hurley III': 88,
#  'Skip Kendall': 8,
#  'Robert Gamez': 16,
#  'Alex Carpenter': 4,
#  'Matt Every': 156,
#  'Brad Faxon': 12,
#  'Andy Bean': 4,
#  'Rod Perry': 24,
#  'Andrew Magee': 8,
#  'Xander Schauffele': 124,
#  'Tommy Fleetwood': 116,
#  'Tony Finau': 156,
#  'Justin Thomas': 148,
#  'Andrew Putnam': 92,
#  'Aaron Wise': 104,
#  'Bryson DeChambeau': 124,
#  'Jason Kokrak': 172,
#  'Brooks Koepka': 136,
#  'Jon Rahm': 108,
#  'Byeong-Hun An': 136,
#  'Austin Cook': 68,
#  'Tyrrell Hatton': 100,
#  'Beau Hossler': 92,
#  'Brice Garnett': 88,
#  'Andrew Landry': 76,
#  'Ted Potter Jr.': 148,
#  'C.T. Pan': 100,
#  'Rafael Cabrera Bello': 128,
#  'Si Woo Kim': 112,
#  'Keith Mitchell': 84,
#  'J.J. Spaun': 76,
#  'Luke List': 112,
#  'Ryan Armour': 88,
#  'Abraham Ancer': 92,
#  'Jordan Spieth': 196,
#  'Emiliano Grillo': 116,
#  'Patton Kizzire': 92,
#  'Chesson Hadley': 108,
#  'Cameron Smith': 132,
#  'Brian Harman': 200,
#  'Thorbjorn Olesen': 80,
#  'Anirban Lahiri': 100,
#  'Kiradech Aphibarnrat': 108,
#  'Ryuko Tokimatsu': 12,
#  'Wade Ormsby': 4,
#  'Li Haotong': 56,
#  'Alexander Bjork': 24,
#  'Russell Knox': 136,
#  'Matthew Fitzpatrick': 72,
#  'Daniel Berger': 108,
#  'Brandon Stone': 24,
#  'Branden Grace': 176,
#  'Satoshi Kodaira': 80,
#  'Paul Dunne': 16,
#  'Kodai Ichihara': 16,
#  'Shubhankar Sharma': 36,
#  'Jaco Ahlers': 4,
#  'Eddie Pepperell': 40,
#  'Erik van Rooyen': 24,
#  'Bernhard Langer': 36,
#  'Danny Willett': 108,
#  'Thomas Pieters': 32,
#  'Julian Suri': 20,
#  'Chris Wood': 44,
#  'Michael Kim': 72,
#  'Cameron Davis': 24,
#  'Ryan Fox': 36,
#  'Masahiro Kawamura': 8,
#  'Tom Lewis': 24,
#  'Sean Crocker': 4,
#  'Yusaku Miyazato': 16,
#  'Lucas Herbert': 12,
#  'Brett Rumford': 20,
#  'Gavin Green': 4,
#  'Marcus Kinhult': 8,
#  'Shaun Norris': 20,
#  'Matthew Southgate': 8,
#  'Rhys Enoch': 8,
#  'Zander Lombard': 8,
#  'Sam Locke': 8,
#  'George Coetzee': 68,
#  'Tom Lehman': 36,
#  'Matt Wallace': 36,
#  'Fabrizio Zanotti': 4,
#  'Andy Sullivan': 32,
#  'Oliver Wilson': 32,
#  'Shane Lowry': 132,
#  'Kelly Kraft': 92,
#  'Jorge Campillo': 16,
#  'Jordan Smith': 8,
#  'Nicolai Hojgaard': 4,
#  'Alexander Levy': 32,
#  'Bronson Burgoon': 56,
#  'Mark Calcavecchia': 36,
#  'Scott Jamieson': 16,
#  'Sang-hyun Park': 8,
#  'Marcus Armitage': 4,
#  'Russell Henley': 144,
#  'Hideto Tanihara': 4,
#  'Haraldur Magnus': 4,
#  'Dylan Frittelli': 60,
#  'Jazz Janewattananond': 16,
#  'Thomas Curtis': 4,
#  'Michael Hendry': 8,
#  'Shota Akiyoshi': 8,
#  'Danthai Boonma': 4,
#  'Jonas Blixt': 136,
#  'Nicolas Colsaerts': 64,
#  'Grant Forrest': 8,
#  'Minchel Choi': 4,
#  'Brady Schnell': 8,
#  'Lin Yuxin (a)': 8,
#  'Masanori Kobayashi': 8,
#  'Ashton Turner': 8,
#  'Jack Senior': 8,
#  'James Robinson': 4,
#  'Jovan Rebula (a)': 16,
#  'Jens Dantorp': 4,
#  'Brian Stuard': 132,
#  'James Hahn': 116,
#  'Danny Lee': 136,
#  'Tom Hoge': 84,
#  'Whee Kim': 76,
#  'Ollie Schniederjans': 88,
#  'Joel Dahmen': 76,
#  'Harold Varner III': 84,
#  'Scott Brown': 136,
#  'Richy Werenski': 52,
#  'Cody Gribble': 40,
#  'Grayson Murray': 56,
#  'Mackenzie Hughes': 56,
#  'Tyrone Van Aswegen': 48,
#  'Brandon Harkins': 48,
#  'Ryan Blaum': 44,
#  'Nick Taylor': 88,
#  'John Huh': 196,
#  'Wesley Bryan': 24,
#  'Robert Streb': 100,
#  'Hudson Swafford': 56,
#  'David Lingmerth': 96,
#  'Trey Mullinax': 48,
#  'Blayne Barber': 44,
#  'Harris English': 172,
#  'Martin Flores': 120,
#  'Patrick Rodgers': 84,
#  'Dominic Bozzelli': 40,
#  'Derek Fathauer': 48,
#  'Bernd Wiesberger': 52,
#  'Doug Ghim': 20,
#  'Doc Redman': 24,
#  'Joaquin Niemann': 60,
#  'Matt Parziale (a)': 12,
#  'Harry Ellis': 12,
#  'Sam Horsfield': 12,
#  'Talor Gooch': 52,
#  'Sam Burns': 52,
#  'Curtis Luck': 8,
#  'Collin Morikawa': 28,
#  'A.J. McInerney': 4,
#  'Tyler Duncan': 56,
#  'Sang-Moon Bae': 168,
#  'Donny Lee': 4,
#  'Smylie Kaufman': 24,
#  'Lanto Griffin': 28,
#  'Maverick McNealy': 12,
#  'Corey Conners': 60,
#  'Tom Lovelady': 20,
#  'Benjamin Silverman': 28,
#  'Roberto Diaz': 16,
#  'J.T. Poston': 56,
#  'Steve Wheatcroft': 48,
#  'Shawn Stefani': 60,
#  'Seamus Power': 40,
#  'Peter Malnati': 48,
#  'Nate Lashley': 36,
#  'Stephan Jaeger': 36,
#  'Jack Maguire': 12,
#  'Brett Stegmaier': 8,
#  'Ethan Tracy': 12,
#  'Will Zalatoris': 12,
#  'Kyle Thompson': 28,
#  'Denny McCarthy': 44,
#  'Zac Blair': 40,
#  'Sam Ryder': 48,
#  'Xin-Jun Zhang': 28,
#  'Norman Xiong': 8,
#  'Rob Oppenheim': 28,
#  'Tyler Torano': 4,
#  'Derek Barron': 4,
#  'Conrad Shindler': 4,
#  'Andrew Yun': 8,
#  'Morgan Hoffmann': 84,
#  'Andrew Loupe': 20,
#  'Nicholas Lindheim': 28,
#  'John Mallinger': 56,
#  'Michael Block': 28,
#  'Adam Schenk': 48,
#  'Jonathan Randolph': 44,
#  'Matt Atkins': 4,
#  'Zecheng Dou': 12,
#  'Dylan Meyer': 12,
#  'Matthieu Pavon': 8,
#  'Tim Wilkinson': 36,
#  'Luis Gagne': 8,
#  'Mickey DeMorat': 4,
#  'Dean Burmester': 8,
#  'Chris Naegel': 4,
#  'Calum Hill': 4,
#  'Andrew Johnston': 12,
#  'Cameron Wilson': 4,
#  'Will Grimmer': 8,
#  'Jason Scrivener': 4,
#  'Eric Axley': 20,
#  'Sungjae Im': 52,
#  'Roberto Castro': 88,
#  'Braden Thornberry': 8,
#  'Sebastian Vazquez': 4,
#  'Ty Strafaci': 8,
#  'Sebastian Munoz': 24,
#  'Cole Miller': 4,
#  'David Bransdon': 4,
#  'Sung Joon Park': 24,
#  'Richie Ramsay': 32,
#  'Paul Waring': 8,
#  'Christopher Babcock': 4,
#  'Rhett Rasmussen (a)': 4,
#  'Stewart Hagestad (a)': 8,
#  'Michael Miller': 4,
#  'Wen-Chong Liang': 12,
#  'Theo Humphrey': 4,
#  'Jacob Bergeron': 8,
#  'Ryan Evans': 4,
#  'David Gazzolo': 4,
#  'Chun An Yu (a)': 8,
#  'Garrett Rank': 4,
#  'Franklin Huang (a)': 4,
#  'Timothy Wiseman (a)': 4,
#  'Kristoffer Reitan': 4,
#  'James Morrison': 20,
#  'Ryan Lumsden (a)': 4,
#  'Rikuya Hoshino': 8,
#  'Shintaro Ban': 4,
#  'Sulman Raza': 4,
#  'Noah Goodwin (a)': 4,
#  'Michael Hebert': 4,
#  'Philip Barbaree': 4,
#  'Scott Gregory': 4,
#  'Ben Kern': 4,
#  'Seung-su Han': 8,
#  'Adrian Otaegui': 16,
#  'Mike Lorenzo-Vera': 12,
#  'Shugo Imahira': 28,
#  'Justin Harding': 24,
#  'Sean McCarty': 4,
#  'Mikko Korhonen': 12,
#  'Paul Broadhurst': 8,
#  'Craig Hocknull': 8,
#  'Zach J. Johnson': 4,
#  'Ryan Vermeer': 8,
#  'Jason Schmuhl': 8,
#  'Matt Dobyns': 12,
#  'Rich Berberian Jr.': 12,
#  'Shawn Warren': 4,
#  'Omar Uresti': 12,
#  'Matthew Borchert': 4,
#  'Craig Bowden': 12,
#  'David Muttitt': 8,
#  'Johan Kok': 8,
#  'Jaysen Hansen': 4,
#  'Haotong Li': 4,
#  'Parker McLachlin': 8,
#  'Richard H. Lee': 60,
#  'Cameron Champ': 40,
#  'Jon Curran': 32,
#  'Scottie Scheffler': 16,
#  'Seunghyuk Kim': 4,
#  'Vinnie Poncino': 4,
#  'Charlie Beljan': 68,
#  'Andrew Novak': 4,
#  'T.J. Vogel': 16,
#  'Jhared Hack': 4,
#  'Andrew Filbert': 8,
#  'Jimmy Stanger': 4,
#  'Andrew Dorn (a)': 4,
#  'John Peterson': 44,
#  'Derek Ernst': 48,
#  'Chris Paisley': 4,
#  'Ryan Ruffels': 4,
#  'Carter Jenkins': 4,
#  'Dru Love': 4,
#  'J.T. Griffin': 4,
#  'Mito Pereira': 8,
#  'Charles Frost': 8,
#  'Kristoffer Ventura': 8,
#  'Matthew Wolff': 16,
#  'Viktor Hovland': 16,
#  'Chan Kim': 12,
#  'Wyndham Clark': 28,
#  'Max Homa': 56,
#  'Tomoharu Otsuki': 4,
#  'Adam Long': 40,
#  'Jinichiro Kozuma': 4,
#  'Yosuke Asaji': 8,
#  'Sanghyun Park': 8,
#  'Mikumu Horikawa': 12,
#  'Kyoung-Hoon Lee': 28,
#  'Carlos Ortiz': 52,
#  'Martin Trainer': 20,
#  'Brendon Todd': 64,
#  'Sepp Straka': 20,
#  'Roger Sloan': 28,
#  'Sean Yu': 4,
#  'Kyongjun Moon': 4,
#  'Harry Higgs': 4,
#  'Will Gordon': 4,
#  'Sebastian Cappelen': 8,
#  'Tyler McCumber': 4,
#  'Matthew NeSmith': 8,
#  'Mark D. Anderson': 32,
#  'Zack Sucher': 20,
#  'Robby Shelton': 4,
#  'Ryan Brehm': 8,
#  'Ben Taylor': 8,
#  'Brandon Wu': 12,
#  'Rhein Gibson': 4,
#  'Chase Seiffert': 4,
#  'Chris Baker': 4,
#  'Brandon Hagy': 16,
#  'Eddie Olson': 4,
#  'KK Limbhasut': 4,
#  'Vincent Whaley': 4,
#  'Michael Gligic': 4,
#  'Vince Covello': 4,
#  'Scott Harrington': 8,
#  'Wes Roach': 8,
#  'Nelson Lauta Ledesma': 4,
#  'Lucas Bjerregaard': 32,
#  'Michael Gellerman': 4,
#  'Hank Lebioda': 8,
#  'Justin Suh': 8,
#  'Bo Hoag': 12,
#  'Henrik Norlander': 12,
#  'Alex Beach': 8,
#  'Harry Hall': 4,
#  'Isaiah Salinda': 4,
#  'Kramer Hickok': 12,
#  'Patrick Martin': 4,
#  'David Lipsky': 24,
#  'Joost Luiten': 52,
#  'Alvaro Ortiz': 8,
#  'Rob Labritz': 12,
#  'Kurt Kitayama': 8,
#  'Tyler Hall': 4,
#  'Ben Cook': 4,
#  'Brian Mackey': 4,
#  'Richard Sterne': 48,
#  'Jason Caron': 4,
#  'Casey Russell': 4,
#  'Justin Bertsch': 4,
#  "John O'Leary": 4,
#  'Stuart Deane': 4,
#  'Jeffrey Schmid': 4,
#  'Cory Schneider': 4,
#  'Jim Knous': 8,
#  'Adam Svensson': 4,
#  'Julian Etulain': 16,
#  'Chris Thompson': 4,
#  'John Chin': 4,
#  'Nick Hardy': 12,
#  'Jose de Jesus Rodriguez': 4,
#  'Chase Wright': 8,
#  'Scott Langley': 76,
#  'Anders Albertson': 8,
#  'Bruce Doucett': 4,
#  'Seth Reeves': 8,
#  'David Pastore': 4,
#  'Kenny Pigman': 4,
#  'Joey Garber': 4,
#  'Kyle Jones': 12,
#  'Tae Hee Lee': 4,
#  "Timothy O'Neal": 8,
#  'Lukas Euler (a)': 4,
#  'Robert MacIntyre': 4,
#  'Andrew Wilson': 4,
#  'Callum Shinkwin': 4,
#  'Benjamin Hebert': 4,
#  'Inn-choon Hwang': 4,
#  'Romain Langasque': 8,
#  'Nino Bertasio': 4,
#  'Yuki Inamori': 4,
#  'James Sugrue (a)': 4,
#  'Connor Syme': 4,
#  'Takumi Kanaya (a)': 8,
#  'Christiaan Bezuidenhout': 4,
#  'Dong-Kyu Jang': 4,
#  'Matthew Baldwin': 12,
#  'Yoshinori Fujimoto': 12,
#  'Doyeob Mun': 4,
#  'Matthias Schmid (a)': 4,
#  'Jake McLeod': 8,
#  'Paul Lawrie': 56,
#  'Robert Rock': 28,
#  'Isidro Benitez': 4,
#  'Gunn Charoenkul': 4,
#  'Andrea Pavan': 4,
#  'Adri Arnaus': 8,
#  'Curtis Knipes (a)': 4,
#  'Garrick Porteous': 8,
#  'Austin Connelly': 4,
#  'Prom Meesawat': 8,
#  'Dimitrios Papadatos': 4,
#  'Thomas Thurloway (a)': 4,
#  'Charlie Danielson': 4,
#  'Andy Pope': 8,
#  'Chandler Eaton (a)': 4,
#  'Justin Walters': 4,
#  'Clement Sordet': 4,
#  'Chip McDaniel': 4,
#  'Michael Thorbjornsen (a)': 4,
#  'Lee Slattery': 16,
#  'Spencer Tibbits (a)': 4,
#  'Hayden Shieh': 4,
#  'Austin Eckroat (a)': 4,
#  'Callum Tarren': 4,
#  'Renato Paratore': 4,
#  'Daniel Hillier': 4,
#  "Kevin O'Connell (a)": 8,
#  'Luke Guthrie': 68,
#  'Connor Arendell': 4,
#  'Cameron Young (a)': 4,
#  'Ryan Sullivan': 8,
#  'Matt Naumec': 4,
#  'Brett Drewitt': 8,
#  'Noah Norton (a)': 4,
#  'Andreas Halvorsen': 4,
#  'Merrick Bremner': 4,
#  'Eric Dietrich': 4,
#  'Devon Bling (a)': 8,
#  'Aaron Rai': 4,
#  'Matthew Millar': 4,
#  'Soren Kjeldsen': 32,
#  'Soren Hansen': 20,
#  'Brad Benjamin (a)': 4,
#  'Shingo Katayama': 8,
#  'Chang-won Han': 4,
#  'Michael Campbell': 16,
#  'Thongchai Jaidee': 68,
#  'Brett Quigley': 16,
#  'Brett Wetterich': 8,
#  'Mathew Goggin': 36,
#  'Graham DeLaet': 112,
#  'Kevin Johnson': 8,
#  'Jeev Milkha Singh': 16,
#  'Matt Hill': 8,
#  'James Nitties': 16,
#  'Chris Smith': 4,
#  'Chris Wilson': 8,
#  'Fred Funk': 12,
#  'Jay Haas': 4,
#  'Michael Allen': 20,
#  'Greg Owen': 84,
#  'Nicholas Thompson': 72,
#  'Ted Purdy': 12,
#  'Jeff Klauk': 20,
#  'Jaco Van Zyl': 20,
#  'Pablo Martin': 8,
#  'Darren Fichardt': 8,
#  'Katsumasa Miyamoto': 12,
#  'Andrew Dodt': 4,
#  'Shunsuke Sonoda': 12,
#  'Thaworn Wiratchant': 20,
#  'Michio Matsumura': 4,
#  'Liang Wen-Chong': 4,
#  'Alistair Presnell': 20,
#  'Pariya Junhasavasdikul': 4,
#  'Simon Khan': 28,
#  'Wu Kang-chun': 4,
#  'Chao Li': 4,
#  'Mardan Mamat': 8,
#  'Hao Yuan': 4,
#  'Ross McGowan': 16,
#  'James Kingston': 4,
#  'Michael Jonzon': 4,
#  'Notah Begay III': 16,
#  'Carlos Franco': 4,
#  'Henrik Bjornstad': 4,
#  'Garth Mulroy': 32,
#  'Roger Tambellini': 8,
#  'David Lutterus': 4,
#  'Courtland Lowe': 4,
#  'Charles Warren': 8,
#  'Rich Barcelo': 8,
#  'Jerod Turner': 4,
#  'Steve Lowery': 4,
#  'Vance Veazey': 4,
#  'Willis Ring': 4,
#  'Jeff Peck': 4,
#  'Greg Kraft': 4,
#  'Ignacio Garrido': 4,
#  'Marcel Siem': 44,
#  'Alejandro Canizares': 12,
#  'Bradley Dredge': 4,
#  'Colm Moriarty': 4,
#  'Zane Scotland': 4,
#  'Danny Chia': 8,
#  'Toru Taniguchi': 32,
#  'Steven Tiley': 12,
#  'Hirofumi Miyase': 4,
#  'Colin Montgomerie': 16,
#  'Andrew Coltart': 4,
#  'Tom Whitehouse': 4,
#  'Eric Chun': 4,
#  'Tano Goya': 12,
#  'Ryuichi Oda': 4,
#  'Gonzalo Fernandez-Castano': 100,
#  'Gareth Maybin': 12,
#  'Koumei Oda': 20,
#  'Loren Roberts': 4,
#  'Philip Archer': 4,
#  'Jean Hugo': 4,
#  'Jamie Abbott': 4,
#  'Kurt Barnes': 8,
#  'Paul Streeter': 4,
#  'Josh Cunliffe': 4,
#  'Nick Faldo': 12,
#  'Victor Dubuisson': 20,
#  'Thomas Levet': 4,
#  'Mark Haastrup': 4,
#  'Jose Manuel Lara': 4,
#  'Gary Clark': 4,
#  'Glen Day': 4,
#  'Ewan Porter': 4,
#  'Laurie Canter': 4,
#  'Simon Edwards': 4,
#  'Tim Thelen': 4,
#  'Troy Pare': 4,
#  'Scott Hebert': 4,
#  'Sonny Skinner': 8,
#  'Stu Ingraham': 4,
#  'Ryan Benzel': 4,
#  'Kyle Flinton': 4,
#  'Rich Steinmetz': 4,
#  'Bruce Smith': 4,
#  'Chip Sullivan': 8,
#  'Keith Ohr': 4,
#  'Mark Sheftic': 8,
#  'Jason Allred': 8,
#  'Craig Barlow': 4,
#  'Matthew Richardson': 4,
#  'Ty Tryon': 4,
#  'Jason Preeo': 4,
#  'Jean-Francois Lucquin': 4,
#  'Hugo Leon': 4,
#  'Azuma Yano': 4,
#  'David Frost': 4,
#  'Kenny Kim': 4,
#  'Steve Allan': 4,
#  'Mikko Ilonen': 32,
#  'Gary Boyd': 8,
#  'Paul Sheehan': 4,
#  'Kaname Yokoo': 4,
#  'Jerry Smith': 4,
#  'Kent Eger': 4,
#  'Rikard Karlberg': 12,
#  'Rafael Echenique': 8,
#  'Mathias Gronberg': 4,
#  'Terry Pilkadaris': 4,
#  'Daniel McCarthy': 4,
#  'Travis Hampshire': 4,
#  'Deane Pappas': 4,
#  'Kevin Phelan (a)': 8,
#  'Alex Martin': 4,
#  'Mark Silvers': 8,
#  'Blaine Peffley': 4,
#  'Bennett Blakeman': 4,
#  'Kyle Reifers': 48,
#  'Brian Campbell': 8,
#  'Brad Fritsch': 20,
#  'Miguel Angel Carballo': 20,
#  'Bobby Wyatt': 4,
#  'Rick Lamb': 4,
#  'Max Rottluff': 4,
#  'Tyler Aldridge': 4,
#  'Todd Baek': 4,
#  'Steven Alker': 28,
#  'Chris Gilley': 8,
#  'Gary Christian': 24,
#  'Troy Kelly': 44,
#  'Will Claxton': 40,
#  'Ken Duke': 100,
#  'Casey Wittenberg': 28,
#  'Aaron Watkins': 8,
#  'Steve LeBrun': 8,
#  'Hunter Hamrick': 4,
#  'Jesse Mueller': 4,
#  'Jeff Curl': 4,
#  'Darron Stiles': 12,
#  'Marc Warren': 24,
#  'Casey Martin': 4,
#  'Alberto Sanchez': 4,
#  'Edward Loar': 20,
#  'Peter Lawrie': 4,
#  'Olin Browne': 4,
#  'Anthony Summers': 4,
#  'Sam Osborne': 4,
#  'Paul Claxton': 4,
#  'Tommy Biershenk': 16,
#  'Tadahiro Takayama': 16,
#  'Brian Gaffney': 12,
#  'Dong-hwan Lee': 4,
#  'Tim Weinhart': 4,
#  'Andy Zhang': 4,
#  'Nick Sherwood': 4,
#  'Scott Smith': 4,
#  'Mark McCormick': 4,
#  'Dennis Miller': 4,
#  'Cole Howard': 4,
#  'Brian Rowell': 4,
#  "Jbe' Kruger": 12,
#  'Gaganjeet Bhullar': 4,
#  'Siddikur Rahman': 4,
#  'Shaaban Hussin': 4,
#  'Scott Hend': 8,
#  'Hank Kuehne': 16,
#  'J.J. Killeen': 32,
#  'Alejandro Garmendia': 4,
#  'Alan Morin': 12,
#  'Bryden MacPherson': 8,
#  'Juvic Pagunsan': 8,
#  'David Lynn': 52,
#  'Darrell Kestner': 4,
#  'Roger Chapman': 4,
#  'Kelly Mitchum': 4,
#  'Frank Bensel Jr.': 4,
#  'Paul Scaletta': 8,
#  'Corey Prugh': 4,
#  'Mark Brown': 12,
#  'Bill Murchison III': 4,
#  'Michael Frye': 4,
#  'Doug Wade': 4,
#  'Michael Hoey': 12,
#  'Toshinori Muto': 8,
#  'Oliver Bekker': 4,
#  'Dale Whitnell': 4,
#  'Adilson Da Silva': 4,
#  'Warren Bennett': 4,
#  'Aaron Townsend': 4,
#  'Nick Cullen': 4,
#  'Scott Pinckney': 20,
#  'Morten Orum Madsen': 8,
#  'Barry Lane': 4,
#  'Alan Dunbar': 8,
#  'Sam Walker': 4,
#  "Steven O'Hara": 4,
#  'Ash Hall': 4,
#  'Brad Kennedy': 4,
#  'Andrew Georgiou': 4,
#  'Prayad Marksaeng': 4,
#  'Elliot Saltman': 4,
#  'Richard Finch': 4,
#  'Grant Veenstra': 4,
#  'Manuel Trappel': 4,
#  'Ian Keenan': 4,
#  'Russ Cochran': 4,
#  'Gavin Coles': 12,
#  'Patrick Sheehan': 12,
#  'Stephen Gangluff': 8,
#  'Marco Dawson': 12,
#  'Frank Adams III': 4,
#  'Nick Flanagan': 4,
#  'Rick Lewallen': 4,
#  'Bryan Bigley': 4,
#  'Neal Lancaster': 16,
#  'Scott Dunlap': 8,
#  'Dudley Hart': 8,
#  'Steve Jones': 4,
#  'Arron Oberholser': 4,
#  'David Damesworth': 4,
#  'Corbin Mills': 4,
#  'Randy Lewis': 4,
#  ...}

# %%
massey_A = massey_A.reindex(massey_A.columns)

# %%
massey_A.head()
# Out:
#                 Jason Dufner  Jim Furyk  Henrik Stenson  Jonas Blixt  \
# Jason Dufner             0.0      460.0           344.0        360.0
# Jim Furyk              460.0        0.0           332.0        264.0
# Henrik Stenson         344.0      332.0             0.0        200.0
# Jonas Blixt            360.0      264.0           200.0          0.0
# Adam Scott             436.0      432.0           336.0        204.0
#
#                 Adam Scott  Scott Piercy  David Toms  Dustin Johnson  \
# Jason Dufner         436.0         528.0       304.0           452.0
# Jim Furyk            432.0         436.0       244.0           464.0
# Henrik Stenson       336.0         280.0       176.0           340.0
# Jonas Blixt          204.0         380.0       172.0           240.0
# Adam Scott             0.0         376.0       184.0           452.0
#
#                 Jason Day  Rory McIlroy  ...  Julien Brun  Gregory Yates  \
# Jason Dufner        456.0         348.0  ...          0.0            4.0
# Jim Furyk           444.0         352.0  ...          0.0            0.0
# Henrik Stenson      340.0         364.0  ...          0.0            4.0
# Jonas Blixt         240.0         172.0  ...          0.0            4.0
# Adam Scott          456.0         436.0  ...          0.0            0.0
#
#                 Jorge Fernandez-Valdes  Frankie Capan  Wil Bateman  \
# Jason Dufner                       0.0            0.0          0.0
# Jim Furyk                          0.0            0.0          0.0
# Henrik Stenson                     0.0            0.0          0.0
# Jonas Blixt                        0.0            0.0          0.0
# Adam Scott                         0.0            0.0          0.0
#
#                 Nacho Elvira  Yoshio Yamamoto  Sammy Schmitz  Jin Cheng  \
# Jason Dufner             4.0              4.0            4.0        4.0
# Jim Furyk                0.0              0.0            0.0        0.0
# Henrik Stenson           0.0              0.0            4.0        4.0
# Jonas Blixt              4.0              4.0            0.0        0.0
# Adam Scott               0.0              0.0            4.0        4.0
#
#                 Paul Chaplet
# Jason Dufner             4.0
# Jim Furyk                0.0
# Henrik Stenson           4.0
# Jonas Blixt              0.0
# Adam Scott               4.0
#
# [5 rows x 2049 columns]

# %%
massey_A = massey_A*-1
massey_A = massey_A.fillna(0)

# %%
massey = pd.Series(massey_dict)
massey
# Out:
# Jason Dufner       53332.0
# Jim Furyk          69029.0
# Henrik Stenson     53406.0
# Jonas Blixt          553.0
# Adam Scott         74409.0
#                     ...
# Nacho Elvira        -138.0
# Yoshio Yamamoto     -666.0
# Sammy Schmitz       -613.0
# Jin Cheng           -702.0
# Paul Chaplet       -1414.0
# Length: 2049, dtype: float64

# %% [markdown]
# ## Build the right hand vector and the diagonal in the Massey matrix

# %%
massey = pd.Series(massey_dict)
v = []
for name in massey_A.index:
    score = massey.loc[name] 
#     v.append(massey[name])
    v.append(score)
    # set the diagonal
    massey_A.loc[name, name] = player_wins[name] + player_losses[name]
v = np.array(v)

# %% [markdown]
# ## Save the Massey matrix as a csv

# %%
massey.sort_values()

# %%
massey_A.to_csv('massey.csv')

# %%
np.savetxt('right_vector.csv', v, delimiter=',')

# %%
len(v), len(massey_A)
# Out:
# (2049, 2049)

# %%
massey_A.index

# %%
r =  np.linalg.solve(massey_A.values, v)

# %%
rating = pd.DataFrame({'player' : massey_A.index.values, 'rating' : r}).set_index('player')

# %%
# rating.sort_values('rating').to_csv('all_rankings')
rating.sort_values('rating').to_csv('total_rankings.csv')

# %%
def get_rankings(rankings, names):
    rank_indexes = np.argsort(rankings)
    ranked_names = [0]*len(names)
    for i in range(len(names)):
        ranked_names[i] = names[rank_indexes[i]]
    ranked_names.reverse()
    return ranked_names

# %%
rating
# Out:
#                    rating
# player
# Jason Dufner     0.605729
# Jim Furyk        0.869469
# Henrik Stenson   0.923348
# Jonas Blixt      0.107360
# Adam Scott       1.152330
# ...                   ...
# Nacho Elvira    -0.237632
# Yoshio Yamamoto -1.237632
# Sammy Schmitz   -1.423859
# Jin Cheng       -1.673859
# Paul Chaplet    -3.673859
#
# [2049 rows x 1 columns]

# %%
ranks = rating.loc[roster].sort_values('rating')

# %%
ranks.to_csv('masters_rankings.csv')

# %%
ranks.tail(50)
# Out:
#                            rating
# player
# Adam Hadwin              0.545666
# Byeong-Hun An            0.575476
# Matt Wallace             0.579568
# Marc Leishman            0.583279
# Shane Lowry              0.589396
# Matthew Fitzpatrick      0.625486
# Joaquin Niemann          0.625544
# Kevin Na                 0.635245
# Ian Poulter              0.644997
# Rafael Cabrera Bello     0.654921
# Gary Woodland            0.656751
# Charles Howell III       0.701193
# Tyrrell Hatton           0.720220
# Francesco Molinari       0.727956
# Charl Schwartzel         0.743892
# Louis Oosthuizen         0.781008
# Bryson DeChambeau        0.804337
# Brandt Snedeker          0.804455
# Xander Schauffele        0.851250
# Zach Johnson             0.854814
# Patrick Reed             0.855972
# Paul Casey               0.862811
# Bubba Watson             0.869264
# Tony Finau               0.922162
# Henrik Stenson           0.923348
# Webb Simpson             0.955695
# Lee Westwood             1.012472
# Sergio Garcia            1.015337
# Christiaan Bezuidenhout  1.017607
# Phil Mickelson           1.025922
# Sungjae Im               1.033092
# Scottie Scheffler        1.034926
# Rickie Fowler            1.058796
# Patrick Cantlay          1.079984
# Erik van Rooyen          1.141827
# Adam Scott               1.152330
# Tiger Woods              1.168148
# Justin Thomas            1.188059
# Collin Morikawa          1.195821
# Brooks Koepka            1.216403
# Tommy Fleetwood          1.225447
# Matt Kuchar              1.245646
# Hideki Matsuyama         1.251524
# Jordan Spieth            1.286936
# Justin Rose              1.301734
# Dustin Johnson           1.369097
# Jason Day                1.381138
# Victor Perez             1.411789
# Rory McIlroy             1.466348
# Jon Rahm                 1.517276

# %%
ranks.sort_values('rank').tail(10)

# %% [markdown]
# ### Make the list one dimensional

# %%
data_list = [] # one dimensional list
for row in data:
     data_list += row

# %%
import pandas as pd

# %%
df = pd.DataFrame(data_list, columns=['winner', "loser"])
df.head()
# Out:
#             winner           loser
# 0  Joaquin Niemann        Tom Hoge
# 1  Joaquin Niemann    Brian Harman
# 2  Joaquin Niemann  Harris English
# 3  Joaquin Niemann    Nate Lashley
# 4  Joaquin Niemann  Richy Werenski

# %%
pd.get_dummies(df['winner']).sum()
# Out:
# Adam Long         136
# Andrew Novak      108
# Austin Cook       136
# Beau Hossler       87
# Brendan Steele    108
#                  ...
# Tom Hoge          152
# Tyler McCumber     98
# Viktor Hovland    142
# Vince Covello      98
# Zack Sucher       124
# Length: 67, dtype: int64

# %%
players = {}
for match in data_list:
    if match[0] not in players:
        players[match[0]] = {'win_against' : [], 'lose_against' : []}
        
    if match[1] not in players:
        players[match[1]] = {'win_against' : [], 'lose_against' : []}
    
    players[match[0]]['win_against'].append(match[1])
    players[match[1]]['lose_against'].append(match[1])

# %%
player_df = pd.DataFrame(players)
player_df.head()
# Out:
#                                                 Joaquin Niemann  \
# win_against   [Tom Hoge, Brian Harman, Harris English, Nate ...
# lose_against                                                 []
#
#                                                        Tom Hoge  \
# win_against   [Brian Harman, Harris English, Nate Lashley, R...
# lose_against                                         [Tom Hoge]
#
#                                                    Brian Harman  \
# win_against   [Sebastian Munoz, Scottie Scheffler, Robby She...
# lose_against                       [Brian Harman, Brian Harman]
#
#                                                  Harris English  \
# win_against   [Sebastian Munoz, Scottie Scheffler, Robby She...
# lose_against                   [Harris English, Harris English]
#
#                                                    Nate Lashley  \
# win_against   [Sebastian Munoz, Scottie Scheffler, Robby She...
# lose_against                       [Nate Lashley, Nate Lashley]
#
#                                                  Richy Werenski  \
# win_against   [Sebastian Munoz, Scottie Scheffler, Robby She...
# lose_against                   [Richy Werenski, Richy Werenski]
#
#                                                 Sebastian Munoz  \
# win_against   [Viktor Hovland, Matt Jones, Mark Hubbard, Lan...
# lose_against  [Sebastian Munoz, Sebastian Munoz, Sebastian M...
#
#                                               Scottie Scheffler  \
# win_against   [Viktor Hovland, Matt Jones, Mark Hubbard, Lan...
# lose_against  [Scottie Scheffler, Scottie Scheffler, Scottie...
#
#                                                   Robby Shelton  \
# win_against   [Viktor Hovland, Matt Jones, Mark Hubbard, Lan...
# lose_against  [Robby Shelton, Robby Shelton, Robby Shelton, ...
#
#                                                  Viktor Hovland  ...  \
# win_against   [Lanto Griffin, Bud Cauley, Austin Cook, Kevin...  ...
# lose_against  [Viktor Hovland, Viktor Hovland, Viktor Hovlan...  ...
#
#                                              Kristoffer Ventura  \
# win_against                                                  []
# lose_against  [Kristoffer Ventura, Kristoffer Ventura, Krist...
#
#                                                      Ryan Blaum  \
# win_against                                                  []
# lose_against  [Ryan Blaum, Ryan Blaum, Ryan Blaum, Ryan Blau...
#
#                                                Brendon de Jonge  \
# win_against                                                  []
# lose_against  [Brendon de Jonge, Brendon de Jonge, Brendon d...
#
#                                               Michael Gellerman  \
# win_against                                                  []
# lose_against  [Michael Gellerman, Michael Gellerman, Michael...
#
#                                                 Conrad Shindler  \
# win_against                                                  []
# lose_against  [Conrad Shindler, Conrad Shindler, Conrad Shin...
#
#                                                  Patton Kizzire  \
# win_against                                                  []
# lose_against  [Patton Kizzire, Patton Kizzire, Patton Kizzir...
#
#                                                  Mason Williams  \
# win_against                                                  []
# lose_against  [Mason Williams, Mason Williams, Mason William...
#
#                                                Freddie Jacobson  \
# win_against                                                  []
# lose_against  [Freddie Jacobson, Freddie Jacobson, Freddie J...
#
#                                                   Shawn Stefani  \
# win_against                                                  []
# lose_against  [Shawn Stefani, Shawn Stefani, Shawn Stefani, ...
#
#                                                       Joe Boros
# win_against                                                  []
# lose_against  [Joe Boros, Joe Boros, Joe Boros, Joe Boros, J...
#
# [2 rows x 154 columns]

# %%
winner_dict = {} # Number of each times a player beat the other (winner is row, loser is col)
total_match_dict = {} # Sum of total number of times each player played the other
for winner in df['winner'].unique():
    winner_dict[winner] = {winner : 0}
    for loser in df[df['winner'] == winner]['loser']:
        if loser not in winner_dict[winner]:
            # They havent played yet
            winner_dict[winner][loser] = 0
            
        winner_dict[winner][loser] += 1

# %%
winner_dict
# Out:
# {'Joaquin Niemann': {'Tom Hoge': 1,
#   'Brian Harman': 1,
#   'Harris English': 1,
#   'Nate Lashley': 1,
#   'Richy Werenski': 1,
#   'Sebastian Munoz': 1,
#   'Scottie Scheffler': 1,
#   'Robby Shelton': 1,
#   'Viktor Hovland': 1,
#   'Matt Jones': 1,
#   'Mark Hubbard': 1,
#   'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Tom Hoge': {'Brian Harman': 1,
#   'Harris English': 1,
#   'Nate Lashley': 1,
#   'Richy Werenski': 1,
#   'Sebastian Munoz': 1,
#   'Scottie Scheffler': 1,
#   'Robby Shelton': 1,
#   'Viktor Hovland': 1,
#   'Matt Jones': 1,
#   'Mark Hubbard': 1,
#   'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Brian Harman': {'Sebastian Munoz': 1,
#   'Scottie Scheffler': 1,
#   'Robby Shelton': 1,
#   'Viktor Hovland': 1,
#   'Matt Jones': 1,
#   'Mark Hubbard': 1,
#   'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Harris English': {'Sebastian Munoz': 1,
#   'Scottie Scheffler': 1,
#   'Robby Shelton': 1,
#   'Viktor Hovland': 1,
#   'Matt Jones': 1,
#   'Mark Hubbard': 1,
#   'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Nate Lashley': {'Sebastian Munoz': 1,
#   'Scottie Scheffler': 1,
#   'Robby Shelton': 1,
#   'Viktor Hovland': 1,
#   'Matt Jones': 1,
#   'Mark Hubbard': 1,
#   'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Richy Werenski': {'Sebastian Munoz': 1,
#   'Scottie Scheffler': 1,
#   'Robby Shelton': 1,
#   'Viktor Hovland': 1,
#   'Matt Jones': 1,
#   'Mark Hubbard': 1,
#   'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Sebastian Munoz': {'Viktor Hovland': 1,
#   'Matt Jones': 1,
#   'Mark Hubbard': 1,
#   'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Scottie Scheffler': {'Viktor Hovland': 1,
#   'Matt Jones': 1,
#   'Mark Hubbard': 1,
#   'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Robby Shelton': {'Viktor Hovland': 1,
#   'Matt Jones': 1,
#   'Mark Hubbard': 1,
#   'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Viktor Hovland': {'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Matt Jones': {'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Mark Hubbard': {'Lanto Griffin': 1,
#   'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Lanto Griffin': {'Bud Cauley': 1,
#   'Austin Cook': 1,
#   'Kevin Na': 1,
#   'Joseph Bramlett': 1,
#   'Adam Long': 1,
#   'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Bud Cauley': {'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Austin Cook': {'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
#   'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Kevin Na': {'Harold Varner III': 1,
#   'Scott Piercy': 1,
#   'Bronson Burgoon': 1,
#   'Harry Higgs': 1,
#   'Sungjae Im': 1,
#   'Nick Taylor': 1,
#   'Rob Oppenheim': 1,
#   'Doc Redman': 1,
#   'Cameron Smith': 1,
#   'Zack Sucher': 1,
#   'Scott Harrington': 1,
#   'Keegan Bradley': 1,
#   'Denny McCarthy': 1,
#   'Doug Ghim': 1,
#   'Morgan Hoffmann': 1,
#   'Sam Ryder': 1,
#   'Scott Brown': 1,
#   'Danny Lee': 1,
#   'Brice Garnett': 1,
#   'Peter Uihlein': 1,
#   'Hank Lebioda': 1,
#   'Cameron Tringale': 1,
#   'Brendan Steele': 1,
#   'Joel Dahmen': 1,
#   'D.J. Trahan': 1,
#   'Andrew Novak': 1,
#   'Grayson Murray': 1,
#   'Mark D. Anderson': 1,
#   'Jonathan Byrd': 1,
#   'Martin Laird': 1,
#   'Bubba Watson': 1,
#   'Sung Kang': 1,
#   'Vince Covello': 1,
#   'Dominic Bozzelli': 1,
#   'Kevin Chappell': 1,
#   'Byeong-Hun An': 1,
#   'Tyler McCumber': 1,
#   'Patrick Rodgers': 1,
#   'David Hearn': 1,
#   'Roberto Castro': 1,
#   'J.J. Spaun': 1,
#   'Rhein Gibson': 1,
#   'Russell Henley': 1,
#   'Jason Dufner': 1,
# ...
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Rhein Gibson': {'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Russell Henley': {'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Jason Dufner': {'Cameron Percy': 1,
#   'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Cameron Percy': {'Johnson Wagner': 1,
#   'Sebastian Cappelen': 1,
#   'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Johnson Wagner': {'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Sebastian Cappelen': {'Robert Streb': 1,
#   'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Robert Streb': {'Beau Hossler': 1,
#   'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1},
#  'Beau Hossler': {'Matt Every': 1,
#   'Nick Watney': 1,
#   'Ted Potter Jr.': 1,
#   'J.B. Holmes': 1,
#   'Bo Hoag': 1,
#   'Seamus Power': 1,
#   'Sepp Straka': 1,
#   'Scott Stallings': 1,
#   'Fabian Gomez': 1,
#   'Jason Kokrak': 1,
#   'Kevin Streelman': 1,
#   'Talor Gooch': 1,
#   'Adam Schenk': 1,
#   'Matthew NeSmith': 1,
#   'Tyler Duncan': 1,
#   'Chase Seiffert': 1,
#   'Zach Johnson': 1,
#   'Ryan Armour': 1,
#   'Bryson DeChambeau': 1,
#   'Sam Burns': 1,
#   'Nelson Lauta Ledesma': 1,
#   'Rafael Campos': 1,
#   'Kyoung-Hoon Lee': 1,
#   'Rod Pampling': 1,
#   'Ben Taylor': 1,
#   'Tom Lewis': 1,
#   'George McNeill': 1,
#   'Jimmy Walker': 1,
#   'Ben Crane': 1,
#   'Boo Weekley': 1,
#   'Carlos Ortiz': 1,
#   'Whee Kim': 1,
#   'Hayden Springer': 1,
#   'Xin-Jun Zhang': 1,
#   'Anirban Lahiri': 1,
#   'Russell Knox': 1,
#   'David Lingmerth': 1,
#   'Brendon Todd': 1,
#   'Kyle Westmoreland': 1,
#   'Wes Roach': 1,
#   'Ryan Brehm': 1,
#   'Brian Stuard': 1,
#   'Jim Herman': 1,
#   'Tim Wilkinson': 1,
#   'Henrik Norlander': 1,
#   'Andrew Landry': 1,
#   'Martin Trainer': 1,
#   'Bill Haas': 1,
#   'Billy Hurley III': 1,
#   'John Huh': 1,
#   'Michael Kim': 1,
#   'Vincent Whaley': 1,
#   'Sang-Moon Bae': 1,
#   'Daniel Summerhays': 1,
#   'Chris Baker': 1,
#   'Michael Gligic': 1,
#   'Steve Allan': 1,
#   'Arjun Atwal': 1,
#   'Roger Sloan': 1,
#   'Branden Grace': 1,
#   'Josh Teater': 1,
#   'Jamie Lovemark': 1,
#   'John Senden': 1,
#   'J.J. Henry': 1,
#   'Shintaro Ban': 1,
#   'Mackenzie Hughes': 1,
#   'Maverick McNealy': 1,
#   'John Daly': 1,
#   'Cameron Davis': 1,
#   'Brandon Hagy': 1,
#   'Zac Blair': 1,
#   'Alex Cejka': 1,
#   'Robert Garrigus': 1,
#   'Davey Jude': 1,
#   'John Rollins': 1,
#   'Kramer Hickok': 1,
#   'D.A. Points': 1,
#   'Kristoffer Ventura': 1,
#   'Ryan Blaum': 1,
#   'Brendon de Jonge': 1,
#   'Michael Gellerman': 1,
#   'Conrad Shindler': 1,
#   'Patton Kizzire': 1,
#   'Mason Williams': 1,
#   'Freddie Jacobson': 1,
#   'Shawn Stefani': 1,
#   'Joe Boros': 1}}

# %% [markdown]
# ### Match Dataframe
# Winner is the row index, column index is the loser.
#
# The value is the number of times that the winner beat the loser.

# %%
match_df = pd.DataFrame(winner_dict).fillna(0).astype(int)

# %%
wins = match_df.sum(axis=1)
losses = match_df.sum(axis=0)
total = wins + losses

# %% [markdown]
# ### Make the vector v

# %%
match_df.head()
# Out:
#                 Joaquin Niemann  Tom Hoge  Brian Harman  Harris English  \
# Tom Hoge                      1         0             0               0
# Brian Harman                  1         1             0               0
# Harris English                1         1             0               0
# Nate Lashley                  1         1             0               0
# Richy Werenski                1         1             0               0
#
#                 Nate Lashley  Richy Werenski  Sebastian Munoz  \
# Tom Hoge                   0               0                0
# Brian Harman               0               0                0
# Harris English             0               0                0
# Nate Lashley               0               0                0
# Richy Werenski             0               0                0
#
#                 Scottie Scheffler  Robby Shelton  Viktor Hovland  ...  \
# Tom Hoge                        0              0               0  ...
# Brian Harman                    0              0               0  ...
# Harris English                  0              0               0  ...
# Nate Lashley                    0              0               0  ...
# Richy Werenski                  0              0               0  ...
#
#                 Roberto Castro  J.J. Spaun  Rhein Gibson  Russell Henley  \
# Tom Hoge                     0           0             0               0
# Brian Harman                 0           0             0               0
# Harris English               0           0             0               0
# Nate Lashley                 0           0             0               0
# Richy Werenski               0           0             0               0
#
#                 Jason Dufner  Cameron Percy  Johnson Wagner  \
# Tom Hoge                   0              0               0
# Brian Harman               0              0               0
# Harris English             0              0               0
# Nate Lashley               0              0               0
# Richy Werenski             0              0               0
#
#                 Sebastian Cappelen  Robert Streb  Beau Hossler
# Tom Hoge                         0             0             0
# Brian Harman                     0             0             0
# Harris English                   0             0             0
# Nate Lashley                     0             0             0
# Richy Werenski                   0             0             0
#
# [5 rows x 67 columns]

# %%
v_series = 1 + (1/2)*(wins - losses)

# %% [markdown]
# Validate v with Tiger Woods

# %%
(1 + (1/2)*(wins['Tiger Woods'] - losses['Tiger Woods'])) == v_series['Tiger Woods']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-69-4563027c84bf> in <module>
# ----> 1 (1 + (1/2)*(wins['Tiger Woods'] - losses['Tiger Woods'])) == v_series['Tiger Woods']
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %% [markdown]
# ### Make the matrix A
#
# We need total matches against each person

# %%
total_matches = {}
for player in match_df: # iterates over rows
    # For every other player
    # add the wins and losses
    if player not in total_matches:
        total_matches[player] = {}
        
    for other in match_df: # for every other player
        if other not in total_matches:
            total_matches[other] = {}
            
        if player == other:
            # Same player make it 2 + total matches
#             total_matches[player][other] = 2 + total[player]
            total_matches[player][other] = 0
            
        else:
            total_matches[player][other] = -1*(match_df.loc[player, other] + match_df.loc[other, player])
            total_matches[other][player] = total_matches[player][other]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Joaquin Niemann'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-213-456cf0fc9ebc> in <module>
#      16
#      17         else:
# ---> 18             total_matches[player][other] = -1*(match_df.loc[player, other] + match_df.loc[other, player])
#      19             total_matches[other][player] = total_matches[player][other]
#      20
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     803     def _getitem_tuple(self, tup):
#     804         try:
# --> 805             return self._getitem_lowerdim(tup)
#     806         except IndexingError:
#     807             pass
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     927         for i, key in enumerate(tup):
#     928             if is_label_like(key) or isinstance(key, tuple):
# --> 929                 section = self._getitem_axis(key, axis=i)
#     930
#     931                 # we have yielded a scalar ?
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1848         # fall thru to straight lookup
#    1849         self._validate_key(key, axis)
# -> 1850         return self._get_label(key, axis=axis)
#    1851
#    1852
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     158             raise IndexingError("no slices here, handle elsewhere")
#     159
# --> 160         return self.obj._xs(label, axis=axis)
#     161
#     162     def _get_loc(self, key: int, axis: int):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3735             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3736         else:
# -> 3737             loc = self.index.get_loc(key)
#    3738
#    3739             if isinstance(loc, np.ndarray):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Joaquin Niemann'

# %% [markdown]
# The values of this dataframe form the matrix A

# %%
total_matches_df = pd.DataFrame(total_matches).astype(int)
total_matches_df.head()
# Out:
#                  Joaquin Niemann  Tom Hoge  Brian Harman  Harris English  \
# Joaquin Niemann                0        -3            -4              -5
# Tom Hoge                      -3         0            -5              -8
# Brian Harman                  -4        -5             0              -5
# Harris English                -5        -8            -5               0
# Nate Lashley                  -2        -2            -1              -2
#
#                  Nate Lashley  Richy Werenski  Sebastian Munoz  \
# Joaquin Niemann            -2              -3               -3
# Tom Hoge                   -2              -5               -6
# Brian Harman               -1              -2               -4
# Harris English             -2              -3               -6
# Nate Lashley                0               0               -3
#
#                  Scottie Scheffler  Robby Shelton  Viktor Hovland  ...  \
# Joaquin Niemann                 -5             -5              -4  ...
# Tom Hoge                        -5             -7              -3  ...
# Brian Harman                    -6             -5              -4  ...
# Harris English                  -6             -8              -4  ...
# Nate Lashley                    -3             -3              -3  ...
#
#                  David Lingmerth  MJ Daffue  Brendon de Jonge  Jay McLuen  \
# Joaquin Niemann               -1          0                -1           0
# Tom Hoge                      -2          0                -1           0
# Brian Harman                  -1          0                -1           0
# Harris English                -2          0                -1           0
# Nate Lashley                  -1          0                -1           0
#
#                  Daniel Chopra  Tom Lewis  Hayden Buckley  Sam Saunders  \
# Joaquin Niemann              0         -2              -1            -1
# Tom Hoge                     0         -2              -1            -3
# Brian Harman                 0         -1              -1            -2
# Harris English              -1         -3              -1            -2
# Nate Lashley                 0         -1               0            -1
#
#                  Rod Perry  Davis Love III
# Joaquin Niemann         -1              -1
# Tom Hoge                -1              -1
# Brian Harman            -1              -3
# Harris English          -1              -3
# Nate Lashley            -1              -1
#
# [5 rows x 303 columns]

# %% [markdown]
# Now we need to make sure that v is in the correct order

# %%
sum_df = total_matches_df.sum()*-1

# %%
sum_df['Tom Hoge']
# Out:
# 969

# %%
total['Tom Hoge']
# Out:
# 1017.0

# %%
total_matches_df['Tom Hoge'].sum() - 1019 + total['Tom Hoge']
# Out:
# 48.0

# %%
import numpy as np

# %%
v_lst = []
for player in total_matches_df: # goes in order of the rows
    v_lst.append(v_series[player])
    
v = np.array(v_lst)

# %%
v[0]
# Out:
# 13.5

# %%
A = total_matches_df.values

# %%
rankings_arr = np.linalg.solve(A, v)

# %%
np.amax(rankings)
# Out:
# 0.25

# %%
rankings = {}
for i in range(len(rankings_arr)):
    rankings[total_matches_df.index[i]] = rankings_arr[i]
rankings = pd.Series(rankings)

# %%
rankings
# Out:
# Joaquin Niemann   -0.438461
# Tom Hoge          -0.553864
# Brian Harman      -0.520519
# Harris English    -0.735778
# Nate Lashley      -0.424828
#                      ...
# Tom Lewis         -0.169049
# Hayden Buckley    -0.417729
# Sam Saunders      -0.125463
# Rod Perry         -0.443530
# Davis Love III    -0.124328
# Length: 303, dtype: float64

# %%
rankings.sort_values()
# Out:
# Rory McIlroy        -0.927810
# Tyrrell Hatton      -0.919660
# Jon Rahm            -0.895888
# Patrick Reed        -0.801863
# Bryson DeChambeau   -0.771709
#                        ...
# Yongjun Bae (a)     -0.016577
# Marcus Kinhult      -0.012190
# Whee Kim             0.001258
# Michael Kim          0.002154
# Yi Keun Chang        0.021820
# Length: 303, dtype: float64

# %%
new_df = pd.DataFrame(pd.concat([rankings, wins, losses, total], axis=1))
# Out:
# /Users/chrisamoroso/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
new_df.head()
# Out:
#                        0    1      2      3
# 3               0.250000    1    1.0    2.0
# Aaron Baddeley -0.457617  364  413.0  777.0
# Aaron Wise     -0.395688  321  309.0  630.0
# Abraham Ancer  -0.603094  279  510.0  789.0
# Adam Hadwin    -0.622431  134  264.0  398.0

# %%
df.sort_values(by=0, axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-136-52c4e7ec5951> in <module>
# ----> 1 df.sort_values(by=0, axis=0)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4991
#    4992             by = by[0]
# -> 4993             k = self._get_label_or_level_values(by, axis=axis)
#    4994
#    4995             if isinstance(ascending, (tuple, list)):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1772             values = self.axes[axis].get_level_values(key)._values
#    1773         else:
# -> 1774             raise KeyError(key)
#    1775
#    1776         # Check for duplicates
#
# KeyError: 0
